# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[0,2,4,6,8]

# %%
plt.plot(x,y,label = '2x',color ="pink",marker = '.',markeredgecolor = "orange")
plt.xlabel("x-axis representation")
plt.ylabel("y-axis representation")
plt.title("Assignment-1")
plt.legend()
plt.show()
