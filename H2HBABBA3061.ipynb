# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
data= pd.read_csv(r"C:\Users\teja\Downloads\H2HBABBA3061.csv")
data.head()
# Out:
#   business_code cust_number  name_customer           clear_date  \
# 0          U001  0200661137        AFFI us  2019-06-26 00:00:00
# 1          U001  0200739534       OK trust  2019-12-11 00:00:00
# 2          U001  0200726979         BJ'S                    NaN
# 3          U001   200769623    WAL-MAR llc  2019-05-02 00:00:00
# 4          U001   200779906  BOZZU systems  2019-05-08 00:00:00
#
#    buisness_year        doc_id posting_date  document_create_date  \
# 0         2019.0  1.929516e+09   2019-06-18              20190619
# 1         2019.0  1.930192e+09   2019-11-25              20191125
# 2         2020.0  1.930750e+09   2020-04-08              20200406
# 3         2019.0  1.929182e+09   2019-04-21              20190420
# 4         2019.0  1.929153e+09   2019-04-22              20190416
#
#    document_create_date.1  due_in_date invoice_currency document type  \
# 0                20190618   20190703.0              USD            RV
# 1                20191125   20191210.0              USD            RV
# 2                20200408   20200423.0              USD            RV
# 3                20190421   20190506.0              USD            RV
# 4                20190422   20190507.0              USD            RV
#
#    posting_id  area_business  total_open_amount  baseline_create_date  \
# 0         1.0            NaN           15472.67            20190618.0
# 1         1.0            NaN           70572.39            20191125.0
# 2         1.0            NaN           17033.75            20200408.0
# 3         1.0            NaN           16756.30            20190421.0
# 4         1.0            NaN           18221.11            20190422.0
#
#   cust_payment_terms    invoice_id  isOpen
# 0               NAA8  1.929516e+09       0
# 1               NAA8  1.930192e+09       0
# 2               NAA8  1.930750e+09       1
# 3               NAH4  1.929182e+09       0
# 4               NAA8  1.929153e+09       0

# %%
#finding the number of unique values
data.nunique()
# Out:
# business_code                 6
# cust_number                1404
# name_customer              4223
# clear_date                  398
# buisness_year                 2
# doc_id                    48769
# posting_date                504
# document_create_date        503
# document_create_date.1      506
# due_in_date                 547
# invoice_currency              2
# document type                 2
# posting_id                    1
# area_business                 0
# total_open_amount         44205
# baseline_create_date        509
# cust_payment_terms           70
# invoice_id                48763
# isOpen                        2
# dtype: int64

# %%
data.isnull().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                10000
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# posting_id                    0
# area_business             50000
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    6
# isOpen                        0
# dtype: int64

# %%
data1=data[data['clear_date'].notnull()].copy()
data1.shape
#I am dividing my data into data1 where clear dates are given
# Out:
# (40000, 19)

# %%
data1.head()
# Out:
#   business_code cust_number  name_customer           clear_date  \
# 0          U001  0200661137        AFFI us  2019-06-26 00:00:00
# 1          U001  0200739534       OK trust  2019-12-11 00:00:00
# 3          U001   200769623    WAL-MAR llc  2019-05-02 00:00:00
# 4          U001   200779906  BOZZU systems  2019-05-08 00:00:00
# 5          U001  0200704045         RA llc  2019-04-24 00:00:00
#
#    buisness_year        doc_id posting_date  document_create_date  \
# 0         2019.0  1.929516e+09   2019-06-18              20190619
# 1         2019.0  1.930192e+09   2019-11-25              20191125
# 3         2019.0  1.929182e+09   2019-04-21              20190420
# 4         2019.0  1.929153e+09   2019-04-22              20190416
# 5         2019.0  1.929113e+09   2019-04-09              20190409
#
#    document_create_date.1  due_in_date invoice_currency document type  \
# 0                20190618   20190703.0              USD            RV
# 1                20191125   20191210.0              USD            RV
# 3                20190421   20190506.0              USD            RV
# 4                20190422   20190507.0              USD            RV
# 5                20190409   20190424.0              USD            RV
#
#    posting_id  area_business  total_open_amount  baseline_create_date  \
# 0         1.0            NaN           15472.67            20190618.0
# 1         1.0            NaN           70572.39            20191125.0
# 3         1.0            NaN           16756.30            20190421.0
# 4         1.0            NaN           18221.11            20190422.0
# 5         1.0            NaN           95331.86            20190409.0
#
#   cust_payment_terms    invoice_id  isOpen
# 0               NAA8  1.929516e+09       0
# 1               NAA8  1.930192e+09       0
# 3               NAH4  1.929182e+09       0
# 4               NAA8  1.929153e+09       0
# 5               NAA8  1.929113e+09       0

# %%
#so see there are no null values for clearing dates in our data1

# %%
data1.isnull().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                    0
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# posting_id                    0
# area_business             40000
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    6
# isOpen                        0
# dtype: int64

# %%
data_null=data[data['clear_date'].isnull()].copy()
data_null

#drop_null have those values where clear_date is null
# Out:
#       business_code cust_number       name_customer clear_date  buisness_year  \
# 2              U001  0200726979              BJ'S          NaN         2020.0
# 7              U001  0100031704    DELHAIZE systems        NaN         2020.0
# 8              U001  0200769623  WAL-MAR foundation        NaN         2020.0
# 13             U001  0200769623  WAL-MAR associates        NaN         2020.0
# 20             U001  0200723794             MID MO         NaN         2020.0
# ...             ...         ...                 ...        ...            ...
# 49983          CA02  0140105847        GORDON F llc        NaN         2020.0
# 49984          U001  0200769623  WAL-MAR associates        NaN         2020.0
# 49988          U001  0200729942             SA corp        NaN         2020.0
# 49996          U001  0200762301   C&S WH associates        NaN         2020.0
# 49997          U001  0200418007          AM systems        NaN         2020.0
#
#              doc_id posting_date  document_create_date  \
# 2      1.930750e+09   2020-04-08              20200406
# 7      1.930685e+09   2020-03-21              20200321
# 8      1.930607e+09   2020-03-05              20200305
# 13     1.930684e+09   2020-03-22              20200321
# 20     1.930747e+09   2020-04-05              20200404
# ...             ...          ...                   ...
# 49983  2.960627e+09   2020-04-07              20200407
# 49984  1.930611e+09   2020-03-06              20200306
# 49988  1.930844e+09   2020-04-30              20200430
# 49996  1.930637e+09   2020-03-11              20200310
# 49997  1.930675e+09   2020-03-24              20200320
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 2                    20200408   20200423.0              USD            RV
# 7                    20200321   20200405.0              USD            RV
# 8                    20200305   20200320.0              USD            RV
# 13                   20200322   20200406.0              USD            RV
# 20                   20200405   20200420.0              USD            RV
# ...                       ...          ...              ...           ...
# 49983                20200407   20200417.0              CAD            RV
# 49984                20200306   20200321.0              USD            RV
# 49988                20200430   20200515.0              USD            RV
# 49996                20200311   20200326.0              USD            RV
# 49997                20200324   20200408.0              USD            RV
#
#        posting_id  area_business  total_open_amount  baseline_create_date  \
# 2             1.0            NaN           17033.75            20200408.0
# 7             1.0            NaN          108430.66            20200321.0
# 8             1.0            NaN           38911.56            20200305.0
# 13            1.0            NaN           44224.52            20200322.0
# 20            1.0            NaN           48532.99            20200405.0
# ...           ...            ...                ...                   ...
# 49983         1.0            NaN           15587.00            20200407.0
# 49984         1.0            NaN           10447.18            20200306.0
# 49988         1.0            NaN           44233.65            20200430.0
# 49996         1.0            NaN           73655.45            20200311.0
# 49997         1.0            NaN             895.96            20200324.0
#
#       cust_payment_terms    invoice_id  isOpen
# 2                   NAA8  1.930750e+09       1
# 7                   NAA8  1.930685e+09       1
# 8                   NAH4  1.930607e+09       1
# 13                  NAH4  1.930684e+09       1
# 20                  NAA8  1.930747e+09       1
# ...                  ...           ...     ...
# 49983               CA10  2.960627e+09       1
# 49984               NAH4  1.930611e+09       1
# 49988               NAA8  1.930844e+09       1
# 49996               NAC6  1.930637e+09       1
# 49997               NAA8  1.930675e+09       1
#
# [10000 rows x 19 columns]

# %%
data_null.nunique()
#checking the number og unique values
# Out:
# business_code                5
# cust_number                646
# name_customer             1743
# clear_date                   0
# buisness_year                1
# doc_id                    9696
# posting_date                83
# document_create_date        87
# document_create_date.1      83
# due_in_date                124
# invoice_currency             2
# document type                1
# posting_id                   1
# area_business                0
# total_open_amount         9016
# baseline_create_date        84
# cust_payment_terms          40
# invoice_id                9696
# isOpen                       1
# dtype: int64

# %%
data_nat=data_null.copy()
# I will use this data_nat at last where Ill predict the expected payment date (clear date of the null values in the data).

# %%
data1.dtypes
# Out:
# business_code              object
# cust_number                object
# name_customer              object
# clear_date                 object
# buisness_year             float64
# doc_id                    float64
# posting_date               object
# document_create_date        int64
# document_create_date.1      int64
# due_in_date               float64
# invoice_currency           object
# document type              object
# posting_id                float64
# area_business             float64
# total_open_amount         float64
# baseline_create_date      float64
# cust_payment_terms         object
# invoice_id                float64
# isOpen                      int64
# dtype: object

# %% [markdown]
# # Preprocessing

# %%
data_null.drop('clear_date',axis=1,inplace=True)

# dropping the clear date in data_null because thats a null column and
#we hav to predict that value.

# %%
dates=['due_in_date','document_create_date','document_create_date.1','baseline_create_date']
dates1=['clear_date','due_in_date','document_create_date','document_create_date.1','baseline_create_date']

#making date and dates1 list sepeartly for conversion of dates column to int str then to datetime datatype 
# because direct conversion give my default value of 1970-01-01

# %%
doc_c_date1=data1['document_create_date.1']=data1['document_create_date.1'].astype('int')
doc_c_date=data1['document_create_date']=data1['document_create_date'].astype('int')

# here i stored two column of data1 into variables so thta later i can find correlation btw them.
#and i can only correlate numeric data but later these column are getting converted to string which creates a problem

# %%
for x in data1[dates]:
    data1[dates]=data1[dates].astype('int')
for x in data_null[dates]:
    data_null[dates]=data_null[dates].astype('int')
    
#earlier I wrote a code to manually convert the dates to int but it looked so unlike python and so later I wrote a for loop.

# %%
for x in data1[dates1]:
    data1[dates1]=data1[dates1].astype('str')
for x in data_null[dates]:
    data_null[dates]=data_null[dates].astype('str')

# %% [raw]
# for x in data1[dates1]:
#     data1[dates1]=pd.to_datetime(data1[dates1],format='%Y-%m-%d').dt.date
#
# i tried using this code but it was giving errors for some date values so i decided to do it manually.

# %% [raw]
# #this is the manual conversion i was talking about.
#
# #converting the dates directly to datetime datatype resets my dates to 1970-01-01 so here I am converting them to
# #int then string and then to datetime
#
# due_date=data1['due_in_date']=data1['due_in_date'].astype('int')
# doc_c_date1=data1['document_create_date.1']=data1['document_create_date.1'].astype('int')
# doc_c_date=data1['document_create_date']=data1['document_create_date'].astype('int')
# base_date=data1['baseline_create_date']=data1['baseline_create_date'].astype('int')
# pos_date=data1['posting_date']=data1['posting_date'].astype('int')
# data1['buisness_year']=data1['buisness_year'].astype('int')

# %%
#converting to string type

data1['due_in_date']=data1['due_in_date'].astype('str')
data1['document_create_date.1']=data1['document_create_date.1'].astype('str')
data1['document_create_date']=data1['document_create_date'].astype('str')
data1['baseline_create_date']=data1['baseline_create_date'].astype('str')
data1['clear_date']=data1['clear_date'].astype('str')
data1['posting_date']=data1['posting_date'].astype('str')

# %%
#converting to Datetime datatype

data1['due_in_date']=pd.to_datetime(data1['due_in_date'],format='%Y-%m-%d').dt.date
data1['clear_date']=pd.to_datetime(data1['clear_date'],format='%Y-%m-%d').dt.date
data1['document_create_date']=pd.to_datetime(data1['document_create_date'],format='%Y-%m-%d').dt.date
data1['document_create_date.1']=pd.to_datetime(data1['document_create_date.1'],format='%Y-%m-%d').dt.date
data1['posting_date']=pd.to_datetime(data1['posting_date'],format='%Y-%m-%d').dt.date
data1['baseline_create_date']=pd.to_datetime(data1['baseline_create_date'],format='%Y-%m-%d').dt.date

# %%
#converting to Datetime datatype

data_null['due_in_date']=pd.to_datetime(data_null['due_in_date'],format='%Y-%m-%d').dt.date
#data_null['clear_date']=pd.to_datetime(data_null['clear_date'],format='%Y-%m-%d').dt.date
data_null['document_create_date']=pd.to_datetime(data_null['document_create_date'],format='%Y-%m-%d').dt.date
data_null['document_create_date.1']=pd.to_datetime(data_null['document_create_date.1'],format='%Y-%m-%d').dt.date
data_null['posting_date']=pd.to_datetime(data_null['posting_date'],format='%Y-%m-%d').dt.date
data_null['baseline_create_date']=pd.to_datetime(data_null['baseline_create_date'],format='%Y-%m-%d').dt.date

# %%
data1[data1['invoice_id'].isnull()].shape
# Out:
# (6, 19)

# %%
data_null
# Out:
#       business_code cust_number       name_customer  buisness_year  \
# 2              U001  0200726979              BJ'S           2020.0
# 7              U001  0100031704    DELHAIZE systems         2020.0
# 8              U001  0200769623  WAL-MAR foundation         2020.0
# 13             U001  0200769623  WAL-MAR associates         2020.0
# 20             U001  0200723794             MID MO          2020.0
# ...             ...         ...                 ...            ...
# 49983          CA02  0140105847        GORDON F llc         2020.0
# 49984          U001  0200769623  WAL-MAR associates         2020.0
# 49988          U001  0200729942             SA corp         2020.0
# 49996          U001  0200762301   C&S WH associates         2020.0
# 49997          U001  0200418007          AM systems         2020.0
#
#              doc_id posting_date document_create_date document_create_date.1  \
# 2      1.930750e+09   2020-04-08           2020-04-06             2020-04-08
# 7      1.930685e+09   2020-03-21           2020-03-21             2020-03-21
# 8      1.930607e+09   2020-03-05           2020-03-05             2020-03-05
# 13     1.930684e+09   2020-03-22           2020-03-21             2020-03-22
# 20     1.930747e+09   2020-04-05           2020-04-04             2020-04-05
# ...             ...          ...                  ...                    ...
# 49983  2.960627e+09   2020-04-07           2020-04-07             2020-04-07
# 49984  1.930611e+09   2020-03-06           2020-03-06             2020-03-06
# 49988  1.930844e+09   2020-04-30           2020-04-30             2020-04-30
# 49996  1.930637e+09   2020-03-11           2020-03-10             2020-03-11
# 49997  1.930675e+09   2020-03-24           2020-03-20             2020-03-24
#
#       due_in_date invoice_currency document type  posting_id  area_business  \
# 2      2020-04-23              USD            RV         1.0            NaN
# 7      2020-04-05              USD            RV         1.0            NaN
# 8      2020-03-20              USD            RV         1.0            NaN
# 13     2020-04-06              USD            RV         1.0            NaN
# 20     2020-04-20              USD            RV         1.0            NaN
# ...           ...              ...           ...         ...            ...
# 49983  2020-04-17              CAD            RV         1.0            NaN
# 49984  2020-03-21              USD            RV         1.0            NaN
# 49988  2020-05-15              USD            RV         1.0            NaN
# 49996  2020-03-26              USD            RV         1.0            NaN
# 49997  2020-04-08              USD            RV         1.0            NaN
#
#        total_open_amount baseline_create_date cust_payment_terms  \
# 2               17033.75           2020-04-08               NAA8
# 7              108430.66           2020-03-21               NAA8
# 8               38911.56           2020-03-05               NAH4
# 13              44224.52           2020-03-22               NAH4
# 20              48532.99           2020-04-05               NAA8
# ...                  ...                  ...                ...
# 49983           15587.00           2020-04-07               CA10
# 49984           10447.18           2020-03-06               NAH4
# 49988           44233.65           2020-04-30               NAA8
# 49996           73655.45           2020-03-11               NAC6
# 49997             895.96           2020-03-24               NAA8
#
#          invoice_id  isOpen
# 2      1.930750e+09       1
# 7      1.930685e+09       1
# 8      1.930607e+09       1
# 13     1.930684e+09       1
# 20     1.930747e+09       1
# ...             ...     ...
# 49983  2.960627e+09       1
# 49984  1.930611e+09       1
# 49988  1.930844e+09       1
# 49996  1.930637e+09       1
# 49997  1.930675e+09       1
#
# [10000 rows x 18 columns]

# %%
data1
# Out:
#       business_code cust_number    name_customer  clear_date  buisness_year  \
# 0              U001  0200661137          AFFI us  2019-06-26         2019.0
# 1              U001  0200739534         OK trust  2019-12-11         2019.0
# 3              U001   200769623      WAL-MAR llc  2019-05-02         2019.0
# 4              U001   200779906    BOZZU systems  2019-05-08         2019.0
# 5              U001  0200704045           RA llc  2019-04-24         2019.0
# ...             ...         ...              ...         ...            ...
# 49993          U001  0200762301       C&S WH llc  2019-02-20         2019.0
# 49994          U001  0200762301      C&S WH corp  2019-10-11         2019.0
# 49995          U001  0100036318  TFC corporation  2019-07-09         2019.0
# 49998          U001  0200752302     KROGER trust  2019-12-31         2019.0
# 49999          U001  0200781803   JRD associates  2019-02-25         2019.0
#
#              doc_id posting_date document_create_date document_create_date.1  \
# 0      1.929516e+09   2019-06-18           2019-06-19             2019-06-18
# 1      1.930192e+09   2019-11-25           2019-11-25             2019-11-25
# 3      1.929182e+09   2019-04-21           2019-04-20             2019-04-21
# 4      1.929153e+09   2019-04-22           2019-04-16             2019-04-22
# 5      1.929113e+09   2019-04-09           2019-04-09             2019-04-09
# ...             ...          ...                  ...                    ...
# 49993  1.928729e+09   2019-02-04           2019-02-03             2019-02-04
# 49994  1.929928e+09   2019-09-27           2019-09-26             2019-09-27
# 49995  1.929532e+09   2019-06-22           2019-06-22             2019-06-22
# 49998  1.930282e+09   2019-12-16           2019-12-14             2019-12-16
# 49999  1.928736e+09   2019-02-04           2019-02-05             2019-02-04
#
#       due_in_date invoice_currency document type  posting_id  area_business  \
# 0      2019-07-03              USD            RV         1.0            NaN
# 1      2019-12-10              USD            RV         1.0            NaN
# 3      2019-05-06              USD            RV         1.0            NaN
# 4      2019-05-07              USD            RV         1.0            NaN
# 5      2019-04-24              USD            RV         1.0            NaN
# ...           ...              ...           ...         ...            ...
# 49993  2019-02-19              USD            RV         1.0            NaN
# 49994  2019-10-12              USD            RV         1.0            NaN
# 49995  2019-07-02              USD            RV         1.0            NaN
# 49998  2019-12-31              USD            RV         1.0            NaN
# 49999  2019-02-24              USD            RV         1.0            NaN
#
#        total_open_amount baseline_create_date cust_payment_terms  \
# 0               15472.67           2019-06-18               NAA8
# 1               70572.39           2019-11-25               NAA8
# 3               16756.30           2019-04-21               NAH4
# 4               18221.11           2019-04-22               NAA8
# 5               95331.86           2019-04-09               NAA8
# ...                  ...                  ...                ...
# 49993           25685.55           2019-02-04               NAC6
# 49994           22972.81           2019-09-27               NAC6
# 49995           39360.48           2019-06-22               NA10
# 49998           17847.94           2019-12-16               NAA8
# 49999            7606.21           2019-02-04               NAD1
#
#          invoice_id  isOpen
# 0      1.929516e+09       0
# 1      1.930192e+09       0
# 3      1.929182e+09       0
# 4      1.929153e+09       0
# 5      1.929113e+09       0
# ...             ...     ...
# 49993  1.928729e+09       0
# 49994  1.929928e+09       0
# 49995  1.929532e+09       0
# 49998  1.930282e+09       0
# 49999  1.928736e+09       0
#
# [40000 rows x 19 columns]

# %%
#checking for errors in the data 

data[data['due_in_date']<data['baseline_create_date']].shape
# Out:
# (0, 19)

# %%
#checking for errors in the data 

data1[data1['clear_date']<data1['baseline_create_date']].shape

#here we got 8 rows where clear data is smaller than create date
#how is this even possible , it has to be an error.
# Out:
# (2, 19)

# %%
#since there is no clear date in data_null so there is no need to check for the anomalys

# %%
data1.shape
# Out:
# (40000, 19)

# %%
data_null.shape
# Out:
# (10000, 18)

# %%
#removing the anomalys from the data1 dataset.
data1.drop(data1[data1['clear_date']<data1['baseline_create_date']].index,index=None,inplace=True)
data1.head()
# Out:
#   business_code cust_number  name_customer  clear_date  buisness_year  \
# 0          U001  0200661137        AFFI us  2019-06-26         2019.0
# 1          U001  0200739534       OK trust  2019-12-11         2019.0
# 3          U001   200769623    WAL-MAR llc  2019-05-02         2019.0
# 4          U001   200779906  BOZZU systems  2019-05-08         2019.0
# 5          U001  0200704045         RA llc  2019-04-24         2019.0
#
#          doc_id posting_date document_create_date document_create_date.1  \
# 0  1.929516e+09   2019-06-18           2019-06-19             2019-06-18
# 1  1.930192e+09   2019-11-25           2019-11-25             2019-11-25
# 3  1.929182e+09   2019-04-21           2019-04-20             2019-04-21
# 4  1.929153e+09   2019-04-22           2019-04-16             2019-04-22
# 5  1.929113e+09   2019-04-09           2019-04-09             2019-04-09
#
#   due_in_date invoice_currency document type  posting_id  area_business  \
# 0  2019-07-03              USD            RV         1.0            NaN
# 1  2019-12-10              USD            RV         1.0            NaN
# 3  2019-05-06              USD            RV         1.0            NaN
# 4  2019-05-07              USD            RV         1.0            NaN
# 5  2019-04-24              USD            RV         1.0            NaN
#
#    total_open_amount baseline_create_date cust_payment_terms    invoice_id  \
# 0           15472.67           2019-06-18               NAA8  1.929516e+09
# 1           70572.39           2019-11-25               NAA8  1.930192e+09
# 3           16756.30           2019-04-21               NAH4  1.929182e+09
# 4           18221.11           2019-04-22               NAA8  1.929153e+09
# 5           95331.86           2019-04-09               NAA8  1.929113e+09
#
#    isOpen
# 0       0
# 1       0
# 3       0
# 4       0
# 5       0

# %%
data1.shape
# Out:
# (39998, 19)

# %%
# we are going to remove this column and also the correlation btw invoice id and doc id is .999 which means they are highly correlated
#thats why well drop this column.

#removing duplicate invoice ids as I think two bills cant have same invoice number
#this has to be a mistake.

'''data1.drop_duplicates('invoice_id',keep='first',inplace=True)
data1.shape'''
# Out:
# "data1.drop_duplicates('invoice_id',keep='first',inplace=True)\ndata1.shape"

# %%
# making the delay column

data1['delay']=(data1['clear_date']-data1['due_in_date']).dt.days

# %%
data1.sort_values(by='document_create_date.1',inplace=True,ignore_index=1,ascending=True)

# sorting the data wrt to document_create_date1

# %%
data1.describe()
# Out:
#        buisness_year        doc_id  posting_id  area_business  \
# count   39998.000000  3.999800e+04     39998.0            0.0
# mean     2019.129656  2.014552e+09         1.0            NaN
# std         0.335929  2.947046e+08         0.0            NaN
# min      2019.000000  1.928499e+09         1.0            NaN
# 25%      2019.000000  1.929179e+09         1.0            NaN
# 50%      2019.000000  1.929726e+09         1.0            NaN
# 75%      2019.000000  1.930206e+09         1.0            NaN
# max      2020.000000  9.500000e+09         1.0            NaN
#
#        total_open_amount    invoice_id   isOpen         delay
# count       39998.000000  3.999200e+04  39998.0  39998.000000
# mean        32370.371031  2.013429e+09      0.0      0.861993
# std         39914.733778  2.800998e+08      0.0     11.340816
# min             1.880000  1.928499e+09      0.0    -78.000000
# 25%          4732.440000  1.929179e+09      0.0     -3.000000
# 50%         17283.500000  1.929726e+09      0.0      0.000000
# 75%         47121.722500  1.930206e+09      0.0      2.000000
# max        813905.360000  2.960617e+09      0.0    546.000000

# %%
import seaborn as sns
sns.boxplot(x=data1['delay'])
plt.ylabel("density")

# this graph show the density of delays 
# max people submitted the payment with 0 delay

# and we can spot some outliers too
# Out:
# Text(0, 0.5, 'density')

# %%
plt.hist(data1['delay'])
plt.xlabel("delay")
plt.ylabel("density")
plt.title("delay range")
# Out:
# Text(0.5, 1.0, 'delay range')

# %% [markdown]
# ### Using IQR to spot and remove outliers in the dataset

# %%
#after many hit and trial i was able to fing my Q3 values to successfully point out my outliers

Q1 = np.percentile(data1['delay'], 1 )  
Q2 = np.percentile(data1['delay'], 50)  
Q3 = np.percentile(data1['delay'], 99.74)

print('Q1 25 percentile of the given data is, ', Q1) 
print('Q1 50 percentile of the given data is, ', Q2) 
print('Q1 75 percentile of the given data is, ', Q3)
# Out:
# Q1 25 percentile of the given data is,  -19.0
# Q1 50 percentile of the given data is,  0.0
# Q1 75 percentile of the given data is,  90.0

# %%
#Calculating Inter-Quartile range(IQR) by getting differnce of Q3 and Q1
IQR = Q3 - Q1  
print('Interquartile range is', IQR)
# Out:
# Interquartile range is 109.0

# %%
#One way to define an outlier is -> anything below Q1 – 1.5 IQR or -> above Q3 + 1.5 IQR.
#This is called the 1.5 x IQR rule.

low_lim = Q1 - 1.5 * IQR 
up_lim = Q3 + 1.5 * IQR 
print('low_limit is', low_lim) 
print('up_limit is', up_lim)
# Out:
# low_limit is -182.5
# up_limit is 253.5

# %%
#Get outliers sum i.e; sum of below low limt and above upper limit 

outlier =[] 
for x in data1['delay']: 
    if ((x> up_lim) or (x<low_lim)): 
         outlier.append(x) 
print(' outlier in the dataset is', outlier)
# Out:
#  outlier in the dataset is [546, 314]

# %%
# remove outliers in delay 
# removing outliers increases the accuracy in prediction

data1.drop(data1[data1['delay']>up_lim].index,index=None,inplace=True)
data1.drop(data1[data1['delay']<low_lim].index,index=None,inplace=True)

# %%
sns.boxplot(x=data1['delay'])
# Out:
# <AxesSubplot:xlabel='delay'>

# %% [markdown]
# ## Train Test Split

# %%
data["cust_number"].value_counts()
# Out:
# 0200769623    11504
# 0200726979     1919
# 0200762301     1595
# 0200759878     1306
# 0200794332     1137
#               ...
# 0100056693        1
# 0100031169        1
# 0200093491        1
# 0140104498        1
# 0200143162        1
# Name: cust_number, Length: 1404, dtype: int64

# %%
 data1.head()
# Out:
#   business_code cust_number        name_customer  clear_date  buisness_year  \
# 1          CA02  0100054173       DIA associates  2019-08-01         2019.0
# 2          U001  0200769623          WAL-MAR llc  2019-01-10         2019.0
# 3          U001  0200769623         WAL-MAR corp  2019-01-09         2019.0
# 4          U001  0200769623           WAL-MAR in  2019-01-15         2019.0
# 5          U001  0200769623  WAL-MAR corporation  2019-01-10         2019.0
#
#          doc_id posting_date document_create_date document_create_date.1  \
# 1  9.500000e+09   2019-03-29           2019-03-29             2018-12-20
# 2  1.928543e+09   2018-12-30           2018-12-30             2018-12-30
# 3  1.928541e+09   2018-12-30           2018-12-29             2018-12-30
# 4  1.928541e+09   2018-12-30           2018-12-29             2018-12-30
# 5  1.928543e+09   2018-12-30           2018-12-30             2018-12-30
#
#   due_in_date invoice_currency document type  posting_id  area_business  \
# 1  2018-12-30              CAD            X2         1.0            NaN
# 2  2019-01-14              USD            RV         1.0            NaN
# 3  2019-01-14              USD            RV         1.0            NaN
# 4  2019-01-14              USD            RV         1.0            NaN
# 5  2019-01-14              USD            RV         1.0            NaN
#
#    total_open_amount baseline_create_date cust_payment_terms    invoice_id  \
# 1           32500.00           2018-12-20               CA10           NaN
# 2             756.28           2018-12-30               NAH4  1.928543e+09
# 3            9632.86           2018-12-30               NAH4  1.928541e+09
# 4           10065.56           2018-12-30               NAH4  1.928541e+09
# 5            7839.12           2018-12-30               NAH4  1.928543e+09
#
#    isOpen  delay
# 1       0    214
# 2       0     -4
# 3       0     -5
# 4       0      1
# 5       0     -4

# %% [markdown]
# ### Applying Train Test split

# %%
from sklearn.model_selection import train_test_split

# %%
#Assign x,y to data payment delayed dataframe
X=data1.drop('delay',axis=1)
y=data1['delay']
data1.shape
# Out:
# (39996, 20)

# %%
#split the data into train and test as test size 20% and train size as 80%

X_train, X_test, y_train, y_test =train_test_split(X,y,shuffle=False,test_size=0.2)

# %%
#get shape and size of train and test set
X_train.shape , X_test.shape
# Out:
# ((31996, 19), (8000, 19))

# %% [markdown]
# ### splitting X_test into X-validation and X_test1

# %%
X_val, X_test1,y_val,y_test1 = train_test_split(X_test,y_test,test_size=.50,shuffle=False)
X_val.shape , X_test1.shape

#((4642, 20), (4642, 20))
# Out:
# ((4000, 19), (4000, 19))

# %% [markdown]
# *****************************************************************

# %% [markdown]
# # EDA

# %% [markdown]
# #### lets do some Data Analysis and Visulaization

# %%
X_train['delay']=pd.DataFrame(y_train,X_train.index)

# %%
plt.figure(figsize=(10,20))
sns.scatterplot(X_train['document_create_date.1'],X_train['delay'])
# Out:
# <AxesSubplot:xlabel='document_create_date.1', ylabel='delay'>

# %%
map_cust_num=X_train.groupby("cust_number")['delay'].mean().to_dict()

X_train['mean_delay']=X_train['cust_number'].map(map_cust_num)

# %%
X_val['mean_delay']=X_val['cust_number'].map(map_cust_num)
X_val['mean_delay'][X_val['mean_delay'].isnull()]= X_train['delay'].mean()

# %%
X_test1['mean_delay']=X_test1['cust_number'].map(map_cust_num)
X_test1['mean_delay'][X_test1['mean_delay'].isnull()]= X_train['delay'].mean()

# %%
X_train['delay'].mean()
# Out:
# 1.0103450431303913

# %%
data_null['mean_delay']=data_null['cust_number'].map(map_cust_num)
data_null['mean_delay'][data_null['mean_delay'].isnull()]= X_train['delay'].mean()

# %%
#removing some constant columns:- 

X_train.drop(columns=['posting_id', 'area_business','isOpen','document_create_date','posting_date','name_customer'],axis=1,inplace=True)
X_test1.drop(columns=['posting_id', 'area_business','isOpen','document_create_date','posting_date','name_customer'],axis=1,inplace=True)
X_val.drop(columns=['posting_id', 'area_business','isOpen','document_create_date','posting_date','name_customer'],axis=1,inplace=True)

# %%
data_null.drop(columns=['posting_id', 'area_business','isOpen','document_create_date','posting_date','name_customer',],axis=1,inplace=True)
data_null.shape
# Out:
# (10000, 13)

# %%
data_null
# Out:
#       business_code cust_number  buisness_year        doc_id  \
# 2              U001  0200726979         2020.0  1.930750e+09
# 7              U001  0100031704         2020.0  1.930685e+09
# 8              U001  0200769623         2020.0  1.930607e+09
# 13             U001  0200769623         2020.0  1.930684e+09
# 20             U001  0200723794         2020.0  1.930747e+09
# ...             ...         ...            ...           ...
# 49983          CA02  0140105847         2020.0  2.960627e+09
# 49984          U001  0200769623         2020.0  1.930611e+09
# 49988          U001  0200729942         2020.0  1.930844e+09
# 49996          U001  0200762301         2020.0  1.930637e+09
# 49997          U001  0200418007         2020.0  1.930675e+09
#
#       document_create_date.1 due_in_date invoice_currency document type  \
# 2                 2020-04-08  2020-04-23              USD            RV
# 7                 2020-03-21  2020-04-05              USD            RV
# 8                 2020-03-05  2020-03-20              USD            RV
# 13                2020-03-22  2020-04-06              USD            RV
# 20                2020-04-05  2020-04-20              USD            RV
# ...                      ...         ...              ...           ...
# 49983             2020-04-07  2020-04-17              CAD            RV
# 49984             2020-03-06  2020-03-21              USD            RV
# 49988             2020-04-30  2020-05-15              USD            RV
# 49996             2020-03-11  2020-03-26              USD            RV
# 49997             2020-03-24  2020-04-08              USD            RV
#
#        total_open_amount baseline_create_date cust_payment_terms  \
# 2               17033.75           2020-04-08               NAA8
# 7              108430.66           2020-03-21               NAA8
# 8               38911.56           2020-03-05               NAH4
# 13              44224.52           2020-03-22               NAH4
# 20              48532.99           2020-04-05               NAA8
# ...                  ...                  ...                ...
# 49983           15587.00           2020-04-07               CA10
# 49984           10447.18           2020-03-06               NAH4
# 49988           44233.65           2020-04-30               NAA8
# 49996           73655.45           2020-03-11               NAC6
# 49997             895.96           2020-03-24               NAA8
#
#          invoice_id  mean_delay
# 2      1.930750e+09    0.945274
# 7      1.930685e+09    0.565972
# 8      1.930607e+09   -2.189099
# 13     1.930684e+09   -2.189099
# 20     1.930747e+09    0.323529
# ...             ...         ...
# 49983  2.960627e+09    6.064516
# 49984  1.930611e+09   -2.189099
# 49988  1.930844e+09   -1.780645
# 49996  1.930637e+09    0.069937
# 49997  1.930675e+09   -2.682927
#
# [10000 rows x 13 columns]

# %%
X_train
# Out:
#       business_code cust_number  clear_date  buisness_year        doc_id  \
# 1              CA02  0100054173  2019-08-01         2019.0  9.500000e+09
# 2              U001  0200769623  2019-01-10         2019.0  1.928543e+09
# 3              U001  0200769623  2019-01-09         2019.0  1.928541e+09
# 4              U001  0200769623  2019-01-15         2019.0  1.928541e+09
# 5              U001  0200769623  2019-01-10         2019.0  1.928543e+09
# ...             ...         ...         ...            ...           ...
# 31993          U001  0200762301  2019-12-03         2019.0  1.930167e+09
# 31994          U001  0200726979  2019-12-03         2019.0  1.930170e+09
# 31995          U001      CCU013  2019-12-20         2019.0  1.930154e+09
# 31996          CA02  0140104423  2019-11-29         2019.0  2.960594e+09
# 31997          U001  0200705742  2019-12-03         2019.0  1.930165e+09
#
#       document_create_date.1 due_in_date invoice_currency document type  \
# 1                 2018-12-20  2018-12-30              CAD            X2
# 2                 2018-12-30  2019-01-14              USD            RV
# 3                 2018-12-30  2019-01-14              USD            RV
# 4                 2018-12-30  2019-01-14              USD            RV
# 5                 2018-12-30  2019-01-14              USD            RV
# ...                      ...         ...              ...           ...
# 31993             2019-11-18  2019-12-03              USD            RV
# 31994             2019-11-18  2019-12-03              USD            RV
# 31995             2019-11-18  2019-11-18              USD            RV
# 31996             2019-11-18  2019-11-30              CAD            RV
# 31997             2019-11-18  2019-12-03              USD            RV
#
#        total_open_amount baseline_create_date cust_payment_terms  \
# 1               32500.00           2018-12-20               CA10
# 2                 756.28           2018-12-30               NAH4
# 3                9632.86           2018-12-30               NAH4
# 4               10065.56           2018-12-30               NAH4
# 5                7839.12           2018-12-30               NAH4
# ...                  ...                  ...                ...
# 31993          181608.95           2019-11-18               NAC6
# 31994             182.70           2019-11-18               NAA8
# 31995             476.14           2019-11-18               NAX2
# 31996           64439.91           2019-11-20               CA10
# 31997           21044.59           2019-11-18               NAA8
#
#          invoice_id  delay  mean_delay
# 1               NaN    214  214.000000
# 2      1.928543e+09     -4   -2.189099
# 3      1.928541e+09     -5   -2.189099
# 4      1.928541e+09      1   -2.189099
# 5      1.928543e+09     -4   -2.189099
# ...             ...    ...         ...
# 31993  1.930167e+09      0    0.069937
# 31994  1.930170e+09      0    0.945274
# 31995  1.930154e+09     32   43.404167
# 31996  2.960594e+09     -1   -0.308511
# 31997  1.930165e+09      0   -6.722936
#
# [31996 rows x 15 columns]

# %% [markdown]
# #### finding correlation between independent variables

# %%
import seaborn as sns
from scipy.stats import pearsonr
import matplotlib.pyplot as plt

# %%
pearsonr(doc_c_date,doc_c_date1)
# Out:
# (0.9845933239629756, 0.0)

# %%
plt.title("doc create date vs doc create date1 (r={0:02f})".format(pearsonr(doc_c_date,doc_c_date1)[0]))
sns.scatterplot(x=doc_c_date,y=doc_c_date1,data=data1)

# doc_c_date1 and doc_c_date are defined above.

# as we can see the data is highly correlated. the Graph is linear with some outliers.
#since these are independent variable , we can drop one of them from our feature lit.
# Out:
# <AxesSubplot:title={'center':'doc create date vs doc create date1 (r=0.984593)'}, xlabel='document_create_date', ylabel='document_create_date.1'>

# %%
plt.title("due day vs delay".format(X_train['total_open_amount'],y_train))
sns.scatterplot(x=X_train['total_open_amount'],y=y_train)
# Out:
# <AxesSubplot:title={'center':'due day vs delay'}, xlabel='total_open_amount', ylabel='delay'>

# %%
data1
# Out:
#       business_code cust_number        name_customer  clear_date  \
# 1              CA02  0100054173       DIA associates  2019-08-01
# 2              U001  0200769623          WAL-MAR llc  2019-01-10
# 3              U001  0200769623         WAL-MAR corp  2019-01-09
# 4              U001  0200769623           WAL-MAR in  2019-01-15
# 5              U001  0200769623  WAL-MAR corporation  2019-01-10
# ...             ...         ...                  ...         ...
# 39993          U001  0200592182              DECA co  2020-03-02
# 39994          U001  0200777735             NASH  us  2020-03-11
# 39995          U001  0200759878           SA systems  2020-03-13
# 39996          U001  0200739941              FOX  us  2020-03-16
# 39997          U001  0200794332      COST associates  2020-03-12
#
#        buisness_year        doc_id posting_date document_create_date  \
# 1             2019.0  9.500000e+09   2019-03-29           2019-03-29
# 2             2019.0  1.928543e+09   2018-12-30           2018-12-30
# 3             2019.0  1.928541e+09   2018-12-30           2018-12-29
# 4             2019.0  1.928541e+09   2018-12-30           2018-12-29
# 5             2019.0  1.928543e+09   2018-12-30           2018-12-30
# ...              ...           ...          ...                  ...
# 39993         2020.0  1.930570e+09   2020-02-26           2020-02-26
# 39994         2020.0  1.930578e+09   2020-02-27           2020-02-27
# 39995         2020.0  1.930574e+09   2020-02-27           2020-02-26
# 39996         2020.0  1.930574e+09   2020-02-27           2020-02-26
# 39997         2020.0  1.930576e+09   2020-02-27           2020-02-27
#
#       document_create_date.1 due_in_date invoice_currency document type  \
# 1                 2018-12-20  2018-12-30              CAD            X2
# 2                 2018-12-30  2019-01-14              USD            RV
# 3                 2018-12-30  2019-01-14              USD            RV
# 4                 2018-12-30  2019-01-14              USD            RV
# 5                 2018-12-30  2019-01-14              USD            RV
# ...                      ...         ...              ...           ...
# 39993             2020-02-26  2020-03-10              USD            RV
# 39994             2020-02-27  2020-05-02              USD            RV
# 39995             2020-02-27  2020-03-13              USD            RV
# 39996             2020-02-27  2020-03-13              USD            RV
# 39997             2020-02-27  2020-03-13              USD            RV
#
#        posting_id  area_business  total_open_amount baseline_create_date  \
# 1             1.0            NaN           32500.00           2018-12-20
# 2             1.0            NaN             756.28           2018-12-30
# 3             1.0            NaN            9632.86           2018-12-30
# 4             1.0            NaN           10065.56           2018-12-30
# 5             1.0            NaN            7839.12           2018-12-30
# ...           ...            ...                ...                  ...
# 39993         1.0            NaN            1693.44           2020-02-16
# 39994         1.0            NaN           47259.54           2020-02-27
# 39995         1.0            NaN           63966.18           2020-02-27
# 39996         1.0            NaN           25360.00           2020-02-27
# 39997         1.0            NaN           51407.61           2020-02-27
#
#       cust_payment_terms    invoice_id  isOpen  delay
# 1                   CA10           NaN       0    214
# 2                   NAH4  1.928543e+09       0     -4
# 3                   NAH4  1.928541e+09       0     -5
# 4                   NAH4  1.928541e+09       0      1
# 5                   NAH4  1.928543e+09       0     -4
# ...                  ...           ...     ...    ...
# 39993               NAM4  1.930570e+09       0     -8
# 39994               NAGD  1.930578e+09       0    -52
# 39995               NAH4  1.930574e+09       0      0
# 39996               NAA8  1.930574e+09       0      3
# 39997               NAAX  1.930576e+09       0     -1
#
# [39996 rows x 20 columns]

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# '''X_tt=X_train.copy()
# #droping nulls from invoice id :-
# X_tt.dropna(subset=['invoice_id'],inplace=True)
#
# #checking correlation between invoice_id and doc_id
#
# from scipy.stats import pearsonr
# pearsonr(X_tt['invoice_id'],X_tt['doc_id'])'''

# %%
#high corr btw independent vars so we can safely drop ione of them

X_train.drop(['invoice_id'],axis=1,inplace=True)
X_test1.drop(['invoice_id'],axis=1,inplace=True)
X_val.drop(['invoice_id'],axis=1,inplace=True)

#and since there are all unique values in doc id so removing that too wont affect our model

X_train.drop(['doc_id'],axis=1,inplace=True)
X_test1.drop(['doc_id'],axis=1,inplace=True)
X_val.drop(['doc_id'],axis=1,inplace=True)

# %%
#doing the same with data_null

data_null.drop(['invoice_id'],axis=1,inplace=True)
data_null.drop(['doc_id'],axis=1,inplace=True)

# %% [markdown]
# #### making features from due date

# %%
#covert X_train format to datetime 
X_train['due_dt_week']=pd.to_datetime(X_train['due_in_date']).dt.week
X_train['due_dt_mon']=pd.to_datetime(X_train['due_in_date']).dt.month
X_train['due_dt_day_of_week']=pd.to_datetime(X_train['due_in_date']).dt.dayofweek

# %%
X_train['due_dt_day']=pd.to_datetime(X_train['due_in_date']).dt.day

# %%
X_test1['due_dt_week']=pd.to_datetime(X_test1['due_in_date']).dt.week
X_test1['due_dt_mon']=pd.to_datetime(X_test1['due_in_date']).dt.month
X_test1['due_dt_day_of_week']=pd.to_datetime(X_test1['due_in_date']).dt.dayofweek

# %%
X_val['due_dt_week']=pd.to_datetime(X_val['due_in_date']).dt.week
X_val['due_dt_mon']=pd.to_datetime(X_val['due_in_date']).dt.month
X_val['due_dt_day_of_week']=pd.to_datetime(X_val['due_in_date']).dt.dayofweek

# %%
data_null['due_dt_week']=pd.to_datetime(data_null['due_in_date']).dt.week
data_null['due_dt_mon']=pd.to_datetime(data_null['due_in_date']).dt.month
data_null['due_dt_day_of_week']=pd.to_datetime(data_null['due_in_date']).dt.dayofweek

# %% [markdown]
# #### plotting some graphs for insight on data

# %%
#get lineplot b/w due date_week and delay 
plt.figure(figsize=(15,5))
sns.lineplot(X_train['due_dt_week'],X_train['delay'],color='green')
# Out:
# <AxesSubplot:xlabel='due_dt_week', ylabel='delay'>

# %%
#lineplot of due date_day-of-week and delay
plt.figure(figsize=(15,5))
sns.lineplot(X_train['due_dt_day_of_week'],X_train['delay'],color='pink')
plt.title('due weekday vs delay')
# Out:
# Text(0.5, 1.0, 'due weekday vs delay')

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x='due_dt_day',y='delay',data=X_train,color='orange')
# Out:
# <AxesSubplot:xlabel='due_dt_day', ylabel='delay'>

# %%
X_train.drop('due_dt_day',axis=1,inplace=True)

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='due_dt_mon',y='delay',data=X_train)
# Out:
# <AxesSubplot:xlabel='due_dt_mon', ylabel='delay'>

# %%
X_train['due_dt_day_of_week'].unique()
# Out:
# array([6, 0, 1, 4, 3, 2, 5], dtype=int64)

# %%
X_train['is_weekend']=np.where(X_train['due_dt_day_of_week']>3,1,0)
X_val['is_weekend']=np.where(X_val['due_dt_day_of_week']>3,1,0)
X_test1['is_weekend']=np.where(X_test1['due_dt_day_of_week']>3,1,0)

# %%
sns.barplot(x='is_weekend',y='delay',data=X_train,hue='invoice_currency')
# Out:
# <AxesSubplot:xlabel='is_weekend', ylabel='delay'>

# %%
sns.lineplot(x='total_open_amount',y='delay',data=X_train)
# Out:
# <AxesSubplot:xlabel='total_open_amount', ylabel='delay'>

# %%
data_null['is_weekend']=np.where(data_null['due_dt_day_of_week']>3,1,0)

# %%
X_train.drop('delay',axis=1,inplace=True)

# %% [markdown]
# #### we cant make any features outof clearing date

# %%
X_train
# Out:
#       business_code cust_number  clear_date  buisness_year  \
# 1              CA02  0100054173  2019-08-01         2019.0
# 2              U001  0200769623  2019-01-10         2019.0
# 3              U001  0200769623  2019-01-09         2019.0
# 4              U001  0200769623  2019-01-15         2019.0
# 5              U001  0200769623  2019-01-10         2019.0
# ...             ...         ...         ...            ...
# 31993          U001  0200762301  2019-12-03         2019.0
# 31994          U001  0200726979  2019-12-03         2019.0
# 31995          U001      CCU013  2019-12-20         2019.0
# 31996          CA02  0140104423  2019-11-29         2019.0
# 31997          U001  0200705742  2019-12-03         2019.0
#
#       document_create_date.1 due_in_date invoice_currency document type  \
# 1                 2018-12-20  2018-12-30              CAD            X2
# 2                 2018-12-30  2019-01-14              USD            RV
# 3                 2018-12-30  2019-01-14              USD            RV
# 4                 2018-12-30  2019-01-14              USD            RV
# 5                 2018-12-30  2019-01-14              USD            RV
# ...                      ...         ...              ...           ...
# 31993             2019-11-18  2019-12-03              USD            RV
# 31994             2019-11-18  2019-12-03              USD            RV
# 31995             2019-11-18  2019-11-18              USD            RV
# 31996             2019-11-18  2019-11-30              CAD            RV
# 31997             2019-11-18  2019-12-03              USD            RV
#
#        total_open_amount baseline_create_date cust_payment_terms  mean_delay  \
# 1               32500.00           2018-12-20               CA10  214.000000
# 2                 756.28           2018-12-30               NAH4   -2.189099
# 3                9632.86           2018-12-30               NAH4   -2.189099
# 4               10065.56           2018-12-30               NAH4   -2.189099
# 5                7839.12           2018-12-30               NAH4   -2.189099
# ...                  ...                  ...                ...         ...
# 31993          181608.95           2019-11-18               NAC6    0.069937
# 31994             182.70           2019-11-18               NAA8    0.945274
# 31995             476.14           2019-11-18               NAX2   43.404167
# 31996           64439.91           2019-11-20               CA10   -0.308511
# 31997           21044.59           2019-11-18               NAA8   -6.722936
#
#        due_dt_week  due_dt_mon  due_dt_day_of_week  is_weekend
# 1               52          12                   6           1
# 2                3           1                   0           0
# 3                3           1                   0           0
# 4                3           1                   0           0
# 5                3           1                   0           0
# ...            ...         ...                 ...         ...
# 31993           49          12                   1           0
# 31994           49          12                   1           0
# 31995           47          11                   0           0
# 31996           48          11                   5           1
# 31997           49          12                   1           0
#
# [31996 rows x 16 columns]

# %%
data_null
# Out:
#       business_code cust_number  buisness_year document_create_date.1  \
# 2              U001  0200726979         2020.0             2020-04-08
# 7              U001  0100031704         2020.0             2020-03-21
# 8              U001  0200769623         2020.0             2020-03-05
# 13             U001  0200769623         2020.0             2020-03-22
# 20             U001  0200723794         2020.0             2020-04-05
# ...             ...         ...            ...                    ...
# 49983          CA02  0140105847         2020.0             2020-04-07
# 49984          U001  0200769623         2020.0             2020-03-06
# 49988          U001  0200729942         2020.0             2020-04-30
# 49996          U001  0200762301         2020.0             2020-03-11
# 49997          U001  0200418007         2020.0             2020-03-24
#
#       due_in_date invoice_currency document type  total_open_amount  \
# 2      2020-04-23              USD            RV           17033.75
# 7      2020-04-05              USD            RV          108430.66
# 8      2020-03-20              USD            RV           38911.56
# 13     2020-04-06              USD            RV           44224.52
# 20     2020-04-20              USD            RV           48532.99
# ...           ...              ...           ...                ...
# 49983  2020-04-17              CAD            RV           15587.00
# 49984  2020-03-21              USD            RV           10447.18
# 49988  2020-05-15              USD            RV           44233.65
# 49996  2020-03-26              USD            RV           73655.45
# 49997  2020-04-08              USD            RV             895.96
#
#       baseline_create_date cust_payment_terms  mean_delay  due_dt_week  \
# 2               2020-04-08               NAA8    0.945274           17
# 7               2020-03-21               NAA8    0.565972           14
# 8               2020-03-05               NAH4   -2.189099           12
# 13              2020-03-22               NAH4   -2.189099           15
# 20              2020-04-05               NAA8    0.323529           17
# ...                    ...                ...         ...          ...
# 49983           2020-04-07               CA10    6.064516           16
# 49984           2020-03-06               NAH4   -2.189099           12
# 49988           2020-04-30               NAA8   -1.780645           20
# 49996           2020-03-11               NAC6    0.069937           13
# 49997           2020-03-24               NAA8   -2.682927           15
#
#        due_dt_mon  due_dt_day_of_week  is_weekend
# 2               4                   3           0
# 7               4                   6           1
# 8               3                   4           1
# 13              4                   0           0
# 20              4                   0           0
# ...           ...                 ...         ...
# 49983           4                   4           1
# 49984           3                   5           1
# 49988           5                   4           1
# 49996           3                   3           0
# 49997           4                   2           0
#
# [10000 rows x 15 columns]

# %%
X_train.drop(['due_in_date','clear_date'],axis=1,inplace=True)
X_val.drop(['due_in_date','clear_date'],axis=1,inplace=True)
X_test1.drop(['due_in_date','clear_date'],axis=1,inplace=True)

# we extracted all the information from the due and clear date now we can safely drop them off.

# %%
data_null.drop(['due_in_date'],axis=1,inplace=True)

# %%
sns.distplot(X_train['total_open_amount'])

#this is highly skewed graph an we cant make much out of it
# Out:
# <AxesSubplot:xlabel='total_open_amount', ylabel='Density'>

# %%
X_train.total_open_amount.hist()
#we cant get much info from here because the scale here is too high 
#so we must perform log normalization on the total open amount to get it into reasonable scale wrt others.
# Out:
# <AxesSubplot:>

# %%
X_train
# Out:
#       business_code cust_number  buisness_year document_create_date.1  \
# 1              CA02  0100054173         2019.0             2018-12-20
# 2              U001  0200769623         2019.0             2018-12-30
# 3              U001  0200769623         2019.0             2018-12-30
# 4              U001  0200769623         2019.0             2018-12-30
# 5              U001  0200769623         2019.0             2018-12-30
# ...             ...         ...            ...                    ...
# 31993          U001  0200762301         2019.0             2019-11-18
# 31994          U001  0200726979         2019.0             2019-11-18
# 31995          U001      CCU013         2019.0             2019-11-18
# 31996          CA02  0140104423         2019.0             2019-11-18
# 31997          U001  0200705742         2019.0             2019-11-18
#
#       invoice_currency document type  total_open_amount baseline_create_date  \
# 1                  CAD            X2           32500.00           2018-12-20
# 2                  USD            RV             756.28           2018-12-30
# 3                  USD            RV            9632.86           2018-12-30
# 4                  USD            RV           10065.56           2018-12-30
# 5                  USD            RV            7839.12           2018-12-30
# ...                ...           ...                ...                  ...
# 31993              USD            RV          181608.95           2019-11-18
# 31994              USD            RV             182.70           2019-11-18
# 31995              USD            RV             476.14           2019-11-18
# 31996              CAD            RV           64439.91           2019-11-20
# 31997              USD            RV           21044.59           2019-11-18
#
#       cust_payment_terms  mean_delay  due_dt_week  due_dt_mon  \
# 1                   CA10  214.000000           52          12
# 2                   NAH4   -2.189099            3           1
# 3                   NAH4   -2.189099            3           1
# 4                   NAH4   -2.189099            3           1
# 5                   NAH4   -2.189099            3           1
# ...                  ...         ...          ...         ...
# 31993               NAC6    0.069937           49          12
# 31994               NAA8    0.945274           49          12
# 31995               NAX2   43.404167           47          11
# 31996               CA10   -0.308511           48          11
# 31997               NAA8   -6.722936           49          12
#
#        due_dt_day_of_week  is_weekend
# 1                       6           1
# 2                       0           0
# 3                       0           0
# 4                       0           0
# 5                       0           0
# ...                   ...         ...
# 31993                   1           0
# 31994                   1           0
# 31995                   0           0
# 31996                   5           1
# 31997                   1           0
#
# [31996 rows x 14 columns]

# %%
#Converting CAD to USD

X_train['total_open_amount'] = np.where((X_train['invoice_currency'] == "CAD")&(X_train['buisness_year']==2019), X_train['total_open_amount']*0.7538, X_train['total_open_amount'])
X_train['total_open_amount'] = np.where((X_train['invoice_currency'] == "CAD")&(X_train['buisness_year']==2020), X_train['total_open_amount']*0.7461, X_train['total_open_amount'])

# %%
X_train
# Out:
#       business_code cust_number  buisness_year document_create_date.1  \
# 1              CA02  0100054173         2019.0             2018-12-20
# 2              U001  0200769623         2019.0             2018-12-30
# 3              U001  0200769623         2019.0             2018-12-30
# 4              U001  0200769623         2019.0             2018-12-30
# 5              U001  0200769623         2019.0             2018-12-30
# ...             ...         ...            ...                    ...
# 31993          U001  0200762301         2019.0             2019-11-18
# 31994          U001  0200726979         2019.0             2019-11-18
# 31995          U001      CCU013         2019.0             2019-11-18
# 31996          CA02  0140104423         2019.0             2019-11-18
# 31997          U001  0200705742         2019.0             2019-11-18
#
#       invoice_currency document type  total_open_amount baseline_create_date  \
# 1                  CAD            X2       24498.500000           2018-12-20
# 2                  USD            RV         756.280000           2018-12-30
# 3                  USD            RV        9632.860000           2018-12-30
# 4                  USD            RV       10065.560000           2018-12-30
# 5                  USD            RV        7839.120000           2018-12-30
# ...                ...           ...                ...                  ...
# 31993              USD            RV      181608.950000           2019-11-18
# 31994              USD            RV         182.700000           2019-11-18
# 31995              USD            RV         476.140000           2019-11-18
# 31996              CAD            RV       48574.804158           2019-11-20
# 31997              USD            RV       21044.590000           2019-11-18
#
#       cust_payment_terms  mean_delay  due_dt_week  due_dt_mon  \
# 1                   CA10  214.000000           52          12
# 2                   NAH4   -2.189099            3           1
# 3                   NAH4   -2.189099            3           1
# 4                   NAH4   -2.189099            3           1
# 5                   NAH4   -2.189099            3           1
# ...                  ...         ...          ...         ...
# 31993               NAC6    0.069937           49          12
# 31994               NAA8    0.945274           49          12
# 31995               NAX2   43.404167           47          11
# 31996               CA10   -0.308511           48          11
# 31997               NAA8   -6.722936           49          12
#
#        due_dt_day_of_week  is_weekend
# 1                       6           1
# 2                       0           0
# 3                       0           0
# 4                       0           0
# 5                       0           0
# ...                   ...         ...
# 31993                   1           0
# 31994                   1           0
# 31995                   0           0
# 31996                   5           1
# 31997                   1           0
#
# [31996 rows x 14 columns]

# %%
#Converting CAD to USD for val

X_val['total_open_amount'] = np.where((X_val['invoice_currency'] == "CAD")&(X_val['buisness_year']==2019), X_val['total_open_amount']*0.7538, X_val['total_open_amount'])
X_val['total_open_amount'] = np.where((X_val['invoice_currency'] == "CAD")&(X_val['buisness_year']==2020), X_val['total_open_amount']*0.7461, X_val['total_open_amount'])

# %%
#Converting CAD to USD for test1
X_test1['total_open_amount'] = np.where((X_test1['invoice_currency'] == "CAD")&(X_test1['buisness_year']==2019), X_test1['total_open_amount']*0.7538, X_test1['total_open_amount'])
X_test1['total_open_amount'] = np.where((X_test1['invoice_currency'] == "CAD")&(X_test1['buisness_year']==2020), X_test1['total_open_amount']*0.7461, X_test1['total_open_amount'])

# %%
#Converting CAD to USD gor data_null
data_null['total_open_amount'] = np.where((data_null['invoice_currency'] == "CAD")&(data_null['buisness_year']==2019), data_null['total_open_amount']*0.7538, data_null['total_open_amount'])
data_null['total_open_amount'] = np.where((data_null['invoice_currency'] == "CAD")&(data_null['buisness_year']==2020), data_null['total_open_amount']*0.7461, data_null['total_open_amount'])

# %%
#although i tried without the currency conversion but the accurarcy was the same.
# there i did binarization since currency column has only 2 values but result was the same.

# %%
X_train['total_open_amount'].describe()
# Out:
# count     31996.000000
# mean      30931.507759
# std       36915.282642
# min           1.880000
# 25%        4446.323852
# 50%       16863.040000
# 75%       45706.392500
# max      813905.360000
# Name: total_open_amount, dtype: float64

# %%
X_train['amnt_log']=np.log(X_train['total_open_amount'])
X_train["amnt_log"].describe()

# the total_open_amount has high values and if i give these values to for comparision the computer will assign high priority to total open amount
# that too when it does not deserve it and in the end give wrong prediction
# so it is important to scale the values before giving the dataset for feature selection.
# Out:
# count    31996.000000
# mean         9.371571
# std          1.783894
# min          0.631272
# 25%          8.399833
# 50%          9.732880
# 75%         10.729993
# max         13.609599
# Name: amnt_log, dtype: float64

# %%
X_test1['amnt_log']=np.log(X_test1['total_open_amount'])
X_val['amnt_log']=np.log(X_val['total_open_amount'])
data_null['amnt_log']=np.log(data_null['total_open_amount'])

# %%
data_null['amnt_log'].describe()
# Out:
# count    10000.000000
# mean         9.441725
# std          1.735484
# min         -0.328504
# 25%          8.532980
# 50%          9.778345
# 75%         10.754329
# max         12.482121
# Name: amnt_log, dtype: float64

# %%
X_val['amnt_log'].describe()
# Out:
# count    4000.000000
# mean        9.486193
# std         1.770591
# min         2.319442
# 25%         8.569737
# 50%         9.865833
# 75%        10.812370
# max        12.956360
# Name: amnt_log, dtype: float64

# %%
X_test1["amnt_log"].describe()
# Out:
# count    4000.000000
# mean        9.420551
# std         1.730130
# min         2.561868
# 25%         8.545201
# 50%         9.749300
# 75%        10.736773
# max        12.789492
# Name: amnt_log, dtype: float64

# %%
plt.figure(figsize=(30,10))
sns.lineplot(X_train['amnt_log'],y_train,color='orange')
# Out:
# <AxesSubplot:xlabel='amnt_log', ylabel='delay'>

# %%
X_train["amnt_log"]=X_train["amnt_log"]+0.4

#since the amount cant be negative so i am adding all the values wiht 0.4 so that the min value(-0.3) will get positive.
#as we cant have amount due in -ves.

X_train.drop("total_open_amount",axis=1,inplace=True)

# %%
X_val["amnt_log"]=X_val["amnt_log"]+1.715
X_val.drop("total_open_amount",axis=1,inplace=True)
X_test1.drop("total_open_amount",axis=1,inplace=True)

# %%
data_null["amnt_log"]=data_null["amnt_log"]+1.8
#since the amount cant be negative so i am adding all the values wiht 1.8 so that the min value will get positive.
data_null.drop("total_open_amount",axis=1,inplace=True)

# %%
sns.distplot(X_train['amnt_log'],color='pink')
plt.title("X_train amount log")

# this graphs makes more sense than the previous high skewed one.
# Out:
# Text(0.5, 1.0, 'X_train amount log')

# %%
X_train.amnt_log.hist()
# Out:
# <AxesSubplot:>

# %%
sns.distplot(data_null['amnt_log'],color='brown')
plt.title("data_null amount log")
# Out:
# Text(0.5, 1.0, 'data_null amount log')

# %% [markdown]
# #### Making feature out of cust_payment_terms

# %%
X_train['cust_payment_terms'].value_counts()
# Out:
# NAA8    12874
# NAH4     8197
# CA10     2497
# NAC6     1096
# NAM4      859
#         ...
# NAD8        1
# 90M7        1
# NATX        1
# NATM        1
# B112        1
# Name: cust_payment_terms, Length: 66, dtype: int64

# %%
#since there are many values with have occurance 1 or low values and if we try to find mean of their occurance then it would be negligible wrt to NAA8 and the others 
# so I am grouping them in a list and later will replace those values with a common one called others

fem=[xdd for xdd in X_train['cust_payment_terms'] if xdd not in ['NAA8','NAH4','CA10','NAC6','NAM4','NAAX']]
fem_val=[xdd1 for xdd1 in X_val['cust_payment_terms'] if xdd1 not in ['NAA8','NAH4','CA10','NAC6','NAM4','NAAX']]
fem_test1=[xdd2 for xdd2 in X_test1['cust_payment_terms'] if xdd2 not in ['NAA8','NAH4','CA10','NAC6','NAM4','NAAX']]

# %%
fem_null=[xdd3 for xdd3 in data_null['cust_payment_terms'] if xdd3 not in ['NAA8','NAH4','CA10','NAC6','NAM4','NAAX']]

# %%
#replacing the list elements with others
X_train['cust_payment_terms'] = X_train['cust_payment_terms'].replace(fem,'others')
X_val['cust_payment_terms'] = X_val['cust_payment_terms'].replace(fem_val,'others')
X_test1['cust_payment_terms'] = X_test1['cust_payment_terms'].replace(fem_test1,'others')

# %%
data_null['cust_payment_terms'] = data_null['cust_payment_terms'].replace(fem_null,'others')

# %%
X_train['cust_payment_terms'].value_counts()
#this reduces the total unique values and we can make a feature out of them.
# Out:
# NAA8      12874
# NAH4       8197
# others     5687
# CA10       2497
# NAC6       1096
# NAM4        859
# NAAX        786
# Name: cust_payment_terms, dtype: int64

# %%
data_null['cust_payment_terms'].value_counts()
# Out:
# NAA8      4047
# NAH4      3062
# others    1221
# CA10       725
# NAC6       431
# NAM4       278
# NAAX       236
# Name: cust_payment_terms, dtype: int64

# %%
X_train['cust_payment_terms'].value_counts(normalize=True)
#this is giving us mean of each value.
# Out:
# NAA8      0.402363
# NAH4      0.256188
# others    0.177741
# CA10      0.078041
# NAC6      0.034254
# NAM4      0.026847
# NAAX      0.024566
# Name: cust_payment_terms, dtype: float64

# %%
data_null['cust_payment_terms'].value_counts(normalize=True)
# Out:
# NAA8      0.4047
# NAH4      0.3062
# others    0.1221
# CA10      0.0725
# NAC6      0.0431
# NAM4      0.0278
# NAAX      0.0236
# Name: cust_payment_terms, dtype: float64

# %%
cus_pay_terms={'NAA8':0.401007,'NAH4':0.297426,'CA10':0.078930,'NAC6':0.035143,'NAM4':0.025179,'NAAX':0.024775,'others':0.174988}
cus_pay_terms

#here i made a list where i inserted value name and the mean of their occurance.
#frequency encoding
# Out:
# {'NAA8': 0.401007,
#  'NAH4': 0.297426,
#  'CA10': 0.07893,
#  'NAC6': 0.035143,
#  'NAM4': 0.025179,
#  'NAAX': 0.024775,
#  'others': 0.174988}

# %%
#mapping the list with train,test,val and data_null.

X_train['cust_payment_terms']=X_train['cust_payment_terms'].map(cus_pay_terms)
X_val['cust_payment_terms']=X_val['cust_payment_terms'].map(cus_pay_terms)
X_test1['cust_payment_terms']=X_test1['cust_payment_terms'].map(cus_pay_terms)
data_null['cust_payment_terms']=data_null['cust_payment_terms'].map(cus_pay_terms)

# %%
X_train
# Out:
#       business_code cust_number  buisness_year document_create_date.1  \
# 1              CA02  0100054173         2019.0             2018-12-20
# 2              U001  0200769623         2019.0             2018-12-30
# 3              U001  0200769623         2019.0             2018-12-30
# 4              U001  0200769623         2019.0             2018-12-30
# 5              U001  0200769623         2019.0             2018-12-30
# ...             ...         ...            ...                    ...
# 31993          U001  0200762301         2019.0             2019-11-18
# 31994          U001  0200726979         2019.0             2019-11-18
# 31995          U001      CCU013         2019.0             2019-11-18
# 31996          CA02  0140104423         2019.0             2019-11-18
# 31997          U001  0200705742         2019.0             2019-11-18
#
#       invoice_currency document type baseline_create_date  cust_payment_terms  \
# 1                  CAD            X2           2018-12-20            0.078930
# 2                  USD            RV           2018-12-30            0.297426
# 3                  USD            RV           2018-12-30            0.297426
# 4                  USD            RV           2018-12-30            0.297426
# 5                  USD            RV           2018-12-30            0.297426
# ...                ...           ...                  ...                 ...
# 31993              USD            RV           2019-11-18            0.035143
# 31994              USD            RV           2019-11-18            0.401007
# 31995              USD            RV           2019-11-18            0.174988
# 31996              CAD            RV           2019-11-20            0.078930
# 31997              USD            RV           2019-11-18            0.401007
#
#        mean_delay  due_dt_week  due_dt_mon  due_dt_day_of_week  is_weekend  \
# 1      214.000000           52          12                   6           1
# 2       -2.189099            3           1                   0           0
# 3       -2.189099            3           1                   0           0
# 4       -2.189099            3           1                   0           0
# 5       -2.189099            3           1                   0           0
# ...           ...          ...         ...                 ...         ...
# 31993    0.069937           49          12                   1           0
# 31994    0.945274           49          12                   1           0
# 31995   43.404167           47          11                   0           0
# 31996   -0.308511           48          11                   5           1
# 31997   -6.722936           49          12                   1           0
#
#         amnt_log
# 1      10.506367
# 2       7.028412
# 3       9.572935
# 4       9.616875
# 5       9.366882
# ...          ...
# 31993  12.509611
# 31994   5.607845
# 31995   6.565712
# 31996  11.190860
# 31997  10.354399
#
# [31996 rows x 14 columns]

# %% [raw]
# #earlier i wrote the full code but later after complteing this file i replaced this with a fore loop you saw above.
#
# X_train['cust_payment_terms'] = X_train['cust_payment_terms'].replace('NAA8',0.401007)
# X_train['cust_payment_terms'] = X_train['cust_payment_terms'].replace('NAH4',0.259977)
# X_train['cust_payment_terms'] = X_train['cust_payment_terms'].replace('CA10',0.078930)
# X_train['cust_payment_terms'] = X_train['cust_payment_terms'].replace('NAC6',0.035143)
# X_train['cust_payment_terms'] = X_train['cust_payment_terms'].replace('NAM4',0.025179)
# X_train['cust_payment_terms'] = X_train['cust_payment_terms'].replace('NAAX',0.024775)
# X_train['cust_payment_terms'] = X_train['cust_payment_terms'].replace('others',0.174988)
#
# X_val['cust_payment_terms'] = X_val['cust_payment_terms'].replace('NAA8',0.401007)
# X_val['cust_payment_terms'] = X_val['cust_payment_terms'].replace('NAH4',0.259977)
# X_val['cust_payment_terms'] = X_val['cust_payment_terms'].replace('CA10',0.078930)
# X_val['cust_payment_terms'] = X_val['cust_payment_terms'].replace('NAC6',0.035143)
# X_val['cust_payment_terms'] = X_val['cust_payment_terms'].replace('NAM4',0.025179)
# X_val['cust_payment_terms'] = X_val['cust_payment_terms'].replace('NAAX',0.024775)
# X_val['cust_payment_terms'] = X_val['cust_payment_terms'].replace('others',0.174988)
#
# X_test1['cust_payment_terms'] = X_test1['cust_payment_terms'].replace('NAA8',0.401007)
# X_test1['cust_payment_terms'] = X_test1['cust_payment_terms'].replace('NAH4',0.259977)
# X_test1['cust_payment_terms'] = X_test1['cust_payment_terms'].replace('CA10',0.078930)
# X_test1['cust_payment_terms'] = X_test1['cust_payment_terms'].replace('NAC6',0.035143)
# X_test1['cust_payment_terms'] = X_test1['cust_payment_terms'].replace('NAM4',0.025179)
# X_test1['cust_payment_terms'] = X_test1['cust_payment_terms'].replace('NAAX',0.024775)
# X_test1['cust_payment_terms'] = X_test1['cust_payment_terms'].replace('others',0.174988)
#
# data_null['cust_payment_terms'] = data_null['cust_payment_terms'].replace('NAA8',0.401007)
# data_null['cust_payment_terms'] = data_null['cust_payment_terms'].replace('NAH4',0.259977)
# data_null['cust_payment_terms'] = data_null['cust_payment_terms'].replace('CA10',0.078930)
# data_null['cust_payment_terms'] = data_null['cust_payment_terms'].replace('NAC6',0.035143)
# data_null['cust_payment_terms'] = data_null['cust_payment_terms'].replace('NAM4',0.025179)
# data_null['cust_payment_terms'] = data_null['cust_payment_terms'].replace('NAAX',0.024775)
# data_null['cust_payment_terms'] = data_null['cust_payment_terms'].replace('others',0.174988)

# %%
X_train['cust_payment_terms']
# Out:
# 1        0.078930
# 2        0.297426
# 3        0.297426
# 4        0.297426
# 5        0.297426
#            ...
# 31993    0.035143
# 31994    0.401007
# 31995    0.174988
# 31996    0.078930
# 31997    0.401007
# Name: cust_payment_terms, Length: 31996, dtype: float64

# %%
X_train
# Out:
#       business_code cust_number  buisness_year document_create_date.1  \
# 1              CA02  0100054173         2019.0             2018-12-20
# 2              U001  0200769623         2019.0             2018-12-30
# 3              U001  0200769623         2019.0             2018-12-30
# 4              U001  0200769623         2019.0             2018-12-30
# 5              U001  0200769623         2019.0             2018-12-30
# ...             ...         ...            ...                    ...
# 31993          U001  0200762301         2019.0             2019-11-18
# 31994          U001  0200726979         2019.0             2019-11-18
# 31995          U001      CCU013         2019.0             2019-11-18
# 31996          CA02  0140104423         2019.0             2019-11-18
# 31997          U001  0200705742         2019.0             2019-11-18
#
#       invoice_currency document type baseline_create_date  cust_payment_terms  \
# 1                  CAD            X2           2018-12-20            0.078930
# 2                  USD            RV           2018-12-30            0.297426
# 3                  USD            RV           2018-12-30            0.297426
# 4                  USD            RV           2018-12-30            0.297426
# 5                  USD            RV           2018-12-30            0.297426
# ...                ...           ...                  ...                 ...
# 31993              USD            RV           2019-11-18            0.035143
# 31994              USD            RV           2019-11-18            0.401007
# 31995              USD            RV           2019-11-18            0.174988
# 31996              CAD            RV           2019-11-20            0.078930
# 31997              USD            RV           2019-11-18            0.401007
#
#        mean_delay  due_dt_week  due_dt_mon  due_dt_day_of_week  is_weekend  \
# 1      214.000000           52          12                   6           1
# 2       -2.189099            3           1                   0           0
# 3       -2.189099            3           1                   0           0
# 4       -2.189099            3           1                   0           0
# 5       -2.189099            3           1                   0           0
# ...           ...          ...         ...                 ...         ...
# 31993    0.069937           49          12                   1           0
# 31994    0.945274           49          12                   1           0
# 31995   43.404167           47          11                   0           0
# 31996   -0.308511           48          11                   5           1
# 31997   -6.722936           49          12                   1           0
#
#         amnt_log
# 1      10.506367
# 2       7.028412
# 3       9.572935
# 4       9.616875
# 5       9.366882
# ...          ...
# 31993  12.509611
# 31994   5.607845
# 31995   6.565712
# 31996  11.190860
# 31997  10.354399
#
# [31996 rows x 14 columns]

# %%
#dropping these values because i can't file them of any use

X_train.drop(['baseline_create_date','document_create_date.1','buisness_year'],axis=1,inplace=True)
X_val.drop(['baseline_create_date','document_create_date.1','buisness_year'],axis=1,inplace=True)
X_test1.drop(['baseline_create_date','document_create_date.1','buisness_year'],axis=1,inplace=True)
data_null.drop(['baseline_create_date','document_create_date.1','buisness_year'],axis=1,inplace=True)

# %% [markdown]
# #### making feature out of business code using frequency encoding

# %%
X_train['business_code'].value_counts()

#here i can see that below 3 values are having very less occrance in the table so ill group them in a category called others.
# Out:
# U001    28878
# CA02     2580
# U013      421
# U002      109
# U005        5
# U007        3
# Name: business_code, dtype: int64

# %% [markdown]
# X_train=pd.concat([X_train,pd.get_dummies(X_train['business_code'])],axis=1)
#
# i tried using dummy variable but it will increase my features by 6 columns and dimensionality will also be a problem btw train and test sets.

# %%
X_train['business_code'].value_counts(normalize=True)
#normalize return proportion 
#ie U001 is at 90% etc...
# Out:
# U001    0.902550
# CA02    0.080635
# U013    0.013158
# U002    0.003407
# U005    0.000156
# U007    0.000094
# Name: business_code, dtype: float64

# %%
# here i did the same thing which I did with cust_payment_terms.
# categorizing low freq values in others category

# %%
X_train['business_code'] = X_train['business_code'].replace(['U002','U005','U007','U013'],'others')

X_val['business_code'] = X_val['business_code'].replace(['U002','U005','U007','U013'],'others')

X_test1['business_code'] = X_test1['business_code'].replace(['U002','U005','U007','U013'],'others')

# %%
data_null['business_code'] = data_null['business_code'].replace(['U002','U005','U007','U013'],'others')

# %%
X_train['business_code'].value_counts(normalize=True)
# Out:
# U001      0.902550
# CA02      0.080635
# others    0.016815
# Name: business_code, dtype: float64

# %% [raw]
# X_train['business_code'] = X_train['business_code'].replace('U001',0.900469)
# X_train['business_code'] = X_train['business_code'].replace('CA02',0.081166)
# X_train['business_code'] = X_train['business_code'].replace('others',0.018366)
#
# X_val['business_code'] = X_val['business_code'].replace('U001',0.900469)
# X_val['business_code'] = X_val['business_code'].replace('CA02',0.081166)
# X_val['business_code'] = X_val['business_code'].replace('others',0.018366)
#
# X_test1['business_code'] = X_test1['business_code'].replace('U001',0.900469)
# X_test1['business_code'] = X_test1['business_code'].replace('CA02',0.081166)
# X_test1['business_code'] = X_test1['business_code'].replace('others',0.018366)

# %%
buss_code={'U001':0.900517,
'CA02':0.081116,
'others':0.018367
}

#dictionary which can be used for mapping which will reduce labour.

# %%
X_train['business_code']=X_train['business_code'].map(buss_code)
X_train
# Out:
#        business_code cust_number invoice_currency document type  \
# 1           0.081116  0100054173              CAD            X2
# 2           0.900517  0200769623              USD            RV
# 3           0.900517  0200769623              USD            RV
# 4           0.900517  0200769623              USD            RV
# 5           0.900517  0200769623              USD            RV
# ...              ...         ...              ...           ...
# 31993       0.900517  0200762301              USD            RV
# 31994       0.900517  0200726979              USD            RV
# 31995       0.900517      CCU013              USD            RV
# 31996       0.081116  0140104423              CAD            RV
# 31997       0.900517  0200705742              USD            RV
#
#        cust_payment_terms  mean_delay  due_dt_week  due_dt_mon  \
# 1                0.078930  214.000000           52          12
# 2                0.297426   -2.189099            3           1
# 3                0.297426   -2.189099            3           1
# 4                0.297426   -2.189099            3           1
# 5                0.297426   -2.189099            3           1
# ...                   ...         ...          ...         ...
# 31993            0.035143    0.069937           49          12
# 31994            0.401007    0.945274           49          12
# 31995            0.174988   43.404167           47          11
# 31996            0.078930   -0.308511           48          11
# 31997            0.401007   -6.722936           49          12
#
#        due_dt_day_of_week  is_weekend   amnt_log
# 1                       6           1  10.506367
# 2                       0           0   7.028412
# 3                       0           0   9.572935
# 4                       0           0   9.616875
# 5                       0           0   9.366882
# ...                   ...         ...        ...
# 31993                   1           0  12.509611
# 31994                   1           0   5.607845
# 31995                   0           0   6.565712
# 31996                   5           1  11.190860
# 31997                   1           0  10.354399
#
# [31996 rows x 11 columns]

# %%
data_null['business_code']=data_null['business_code'].map(buss_code)
X_test1['business_code']=X_test1['business_code'].map(buss_code)
X_val['business_code']=X_val['business_code'].map(buss_code)

# %% [raw]
# data_null['business_code'] = data_null['business_code'].replace('U001',0.900469)
# data_null['business_code'] = data_null['business_code'].replace('CA02',0.081166)
# data_null['business_code'] = data_null['business_code'].replace('others',0.018366)

# %%
X_train
# Out:
#        business_code cust_number invoice_currency document type  \
# 1           0.081116  0100054173              CAD            X2
# 2           0.900517  0200769623              USD            RV
# 3           0.900517  0200769623              USD            RV
# 4           0.900517  0200769623              USD            RV
# 5           0.900517  0200769623              USD            RV
# ...              ...         ...              ...           ...
# 31993       0.900517  0200762301              USD            RV
# 31994       0.900517  0200726979              USD            RV
# 31995       0.900517      CCU013              USD            RV
# 31996       0.081116  0140104423              CAD            RV
# 31997       0.900517  0200705742              USD            RV
#
#        cust_payment_terms  mean_delay  due_dt_week  due_dt_mon  \
# 1                0.078930  214.000000           52          12
# 2                0.297426   -2.189099            3           1
# 3                0.297426   -2.189099            3           1
# 4                0.297426   -2.189099            3           1
# 5                0.297426   -2.189099            3           1
# ...                   ...         ...          ...         ...
# 31993            0.035143    0.069937           49          12
# 31994            0.401007    0.945274           49          12
# 31995            0.174988   43.404167           47          11
# 31996            0.078930   -0.308511           48          11
# 31997            0.401007   -6.722936           49          12
#
#        due_dt_day_of_week  is_weekend   amnt_log
# 1                       6           1  10.506367
# 2                       0           0   7.028412
# 3                       0           0   9.572935
# 4                       0           0   9.616875
# 5                       0           0   9.366882
# ...                   ...         ...        ...
# 31993                   1           0  12.509611
# 31994                   1           0   5.607845
# 31995                   0           0   6.565712
# 31996                   5           1  11.190860
# 31997                   1           0  10.354399
#
# [31996 rows x 11 columns]

# %%
data_null
# Out:
#        business_code cust_number invoice_currency document type  \
# 2           0.900517  0200726979              USD            RV
# 7           0.900517  0100031704              USD            RV
# 8           0.900517  0200769623              USD            RV
# 13          0.900517  0200769623              USD            RV
# 20          0.900517  0200723794              USD            RV
# ...              ...         ...              ...           ...
# 49983       0.081116  0140105847              CAD            RV
# 49984       0.900517  0200769623              USD            RV
# 49988       0.900517  0200729942              USD            RV
# 49996       0.900517  0200762301              USD            RV
# 49997       0.900517  0200418007              USD            RV
#
#        cust_payment_terms  mean_delay  due_dt_week  due_dt_mon  \
# 2                0.401007    0.945274           17           4
# 7                0.401007    0.565972           14           4
# 8                0.297426   -2.189099           12           3
# 13               0.297426   -2.189099           15           4
# 20               0.401007    0.323529           17           4
# ...                   ...         ...          ...         ...
# 49983            0.078930    6.064516           16           4
# 49984            0.297426   -2.189099           12           3
# 49988            0.401007   -1.780645           20           5
# 49996            0.035143    0.069937           13           3
# 49997            0.401007   -2.682927           15           4
#
#        due_dt_day_of_week  is_weekend   amnt_log
# 2                       3           0  11.542952
# 7                       6           1  13.393866
# 8                       4           1  12.369047
# 13                      0           0  12.497035
# 20                      0           0  12.589999
# ...                   ...         ...        ...
# 49983                   4           1  11.161297
# 49984                   5           1  11.054087
# 49988                   4           1  12.497241
# 49996                   3           0  13.007153
# 49997                   2           0   8.597896
#
# [10000 rows x 11 columns]

# %% [markdown]
# #### checking the dimension of all the datasets before moving forward

# %%
X_train.shape, X_test1.shape , X_val.shape , data_null.shape
# Out:
# ((31996, 11), (4000, 11), (4000, 11), (10000, 11))

# %% [markdown]
# #### making a feature out of document type using binarization

# %%
X_train['doc_type']=np.where(X_train['document type']=="RV",1,0)
X_train.drop("document type",axis=1,inplace=True)

X_val['doc_type']=np.where(X_val['document type']=="RV",1,0)
X_val.drop("document type",axis=1,inplace=True)

X_test1['doc_type']=np.where(X_test1['document type']=="RV",1,0)
X_test1.drop("document type",axis=1,inplace=True)

data_null['doc_type']=np.where(data_null['document type']=="RV",1,0)
data_null.drop("document type",axis=1,inplace=True)

# %%
X_train['invoice_currency'].value_counts()
# Out:
# USD    29414
# CAD     2582
# Name: invoice_currency, dtype: int64

# %%
# Earlier i tried binariztion with invoive currency too

'''X_train['invoice_currency']=np.where(X_train['invoice_currency']=="USD",1,0)

X_val['invoice_currency']=np.where(X_val['invoice_currency']=="USD",1,0)

X_test1['invoice_currency']=np.where(X_test1['invoice_currency']=="USD",1,0)
'''
# Out:
# 'X_train[\'invoice_currency\']=np.where(X_train[\'invoice_currency\']=="USD",1,0)\n\nX_val[\'invoice_currency\']=np.where(X_val[\'invoice_currency\']=="USD",1,0)\n\nX_test1[\'invoice_currency\']=np.where(X_test1[\'invoice_currency\']=="USD",1,0)\n'

# %%
'''data_null['invoice_currency']=np.where(data_null['invoice_currency']=="USD",1,0)
'''
# Out:
# 'data_null[\'invoice_currency\']=np.where(data_null[\'invoice_currency\']=="USD",1,0)\n'

# %%
X_train.shape
# Out:
# (31996, 11)

# %%
# dropping customer number because i took out the mean delay with its help and now i dont need it anymore

# %%
X_train.drop("cust_number",axis=1,inplace=True)
X_val.drop("cust_number",axis=1,inplace=True)
X_test1.drop("cust_number",axis=1,inplace=True)
data_null.drop("cust_number",axis=1,inplace=True)

# %%
# after currency conversion this column makes no sense so i am dropping it off

# %%
X_train.drop("invoice_currency",axis=1,inplace=True)
X_val.drop("invoice_currency",axis=1,inplace=True)
X_test1.drop("invoice_currency",axis=1,inplace=True)

data_null.drop("invoice_currency",axis=1,inplace=True)

# %%
X_train
# Out:
#        business_code  cust_payment_terms  mean_delay  due_dt_week  due_dt_mon  \
# 1           0.081116            0.078930  214.000000           52          12
# 2           0.900517            0.297426   -2.189099            3           1
# 3           0.900517            0.297426   -2.189099            3           1
# 4           0.900517            0.297426   -2.189099            3           1
# 5           0.900517            0.297426   -2.189099            3           1
# ...              ...                 ...         ...          ...         ...
# 31993       0.900517            0.035143    0.069937           49          12
# 31994       0.900517            0.401007    0.945274           49          12
# 31995       0.900517            0.174988   43.404167           47          11
# 31996       0.081116            0.078930   -0.308511           48          11
# 31997       0.900517            0.401007   -6.722936           49          12
#
#        due_dt_day_of_week  is_weekend   amnt_log  doc_type
# 1                       6           1  10.506367         0
# 2                       0           0   7.028412         1
# 3                       0           0   9.572935         1
# 4                       0           0   9.616875         1
# 5                       0           0   9.366882         1
# ...                   ...         ...        ...       ...
# 31993                   1           0  12.509611         1
# 31994                   1           0   5.607845         1
# 31995                   0           0   6.565712         1
# 31996                   5           1  11.190860         1
# 31997                   1           0  10.354399         1
#
# [31996 rows x 9 columns]

# %% [markdown]
# # Feature Selection

# %% [markdown]
# #### applying filter method

# %%
from sklearn.feature_selection import VarianceThreshold
#Passing a value of zero for the parameter will filter all the features with zero variance
constant_filter = VarianceThreshold(threshold=0)
#we need to simply apply this filter to our training set as shown in the following example
constant_filter.fit(X_train)
#the number of non-constant features.
len(X_train.columns[constant_filter.get_support()])
# Out:
# 9

# %%
constant_columns = [column for column in X_train.columns
                    if column not in X_train.columns[constant_filter.get_support()]]

print(len(constant_columns))

#this shows we dont have any constant columns
# Out:
# 0

# %% [markdown]
# #### Correlation Coefficient

# %%
train=X_train.copy()
corr=train.corr()
plt.figure(figsize=(14,9))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [raw]
# # after reading the heat map we can drop either of due_dt_week or due_dt_mon
# # because of their high correlation but ill do that later.

# %% [markdown]
# #### EMBEDDED METHOD

# %%
#this will tell us the feature importance of our model

def tree_based_feature_importance(x_train,y_train):
    from sklearn.ensemble import RandomForestRegressor
    # create the random forest model
    model = RandomForestRegressor(n_estimators=120)

    # fit the model to start training.
    model.fit(X_train, y_train)

    # get the importance of the resulting features.
    importances = model.feature_importances_

    # create a data frame for visualization.
    final_df = pd.DataFrame({"Features": X_train.columns, "Importances":importances})
    final_df.set_index('Importances')

    # sort in descending order 
    final_df = final_df.sort_values('Importances',ascending=False)
    
    #visualising feature importance
    pd.Series(model.feature_importances_, index=X_train.columns).nlargest(6).plot(kind='barh')  
    return final_df

# %%
feature_importance=tree_based_feature_importance(X_train,y_train)

# %%
display(feature_importance)
# Out:
#              Features  Importances
# 2          mean_delay     0.579018
# 7            amnt_log     0.210962
# 3         due_dt_week     0.085035
# 5  due_dt_day_of_week     0.041116
# 1  cust_payment_terms     0.037224
# 4          due_dt_mon     0.028396
# 0       business_code     0.008126
# 6          is_weekend     0.006897
# 8            doc_type     0.003226

# %%
X_train.describe()
# Out:
#        business_code  cust_payment_terms    mean_delay   due_dt_week  \
# count   31996.000000        31996.000000  31996.000000  31996.000000
# mean        0.819612            0.277298      1.010345     26.038411
# std         0.246335            0.128355      7.787918     13.184813
# min         0.018367            0.024775    -50.000000      1.000000
# 25%         0.900517            0.174988     -2.189099     15.000000
# 50%         0.900517            0.297426      0.323529     26.000000
# 75%         0.900517            0.401007      1.411043     37.000000
# max         0.900517            0.401007    214.000000     52.000000
#
#          due_dt_mon  due_dt_day_of_week    is_weekend      amnt_log  \
# count  31996.000000        31996.000000  31996.000000  31996.000000
# mean       6.368765            3.079416      0.436398      9.771571
# std        3.037001            1.875373      0.495946      1.783894
# min        1.000000            0.000000      0.000000      1.031272
# 25%        4.000000            2.000000      0.000000      8.799833
# 50%        6.000000            3.000000      0.000000     10.132880
# 75%        9.000000            5.000000      1.000000     11.129993
# max       12.000000            6.000000      1.000000     14.009599
#
#            doc_type
# count  31996.000000
# mean       0.999844
# std        0.012500
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %% [markdown]
# #### checking for any null values in our datasets before feeding it to the models

# %%
X_train.isnull().sum() , X_val.isnull().sum() , X_test1.isnull().sum()
# Out:
# (business_code         0
#  cust_payment_terms    0
#  mean_delay            0
#  due_dt_week           0
#  due_dt_mon            0
#  due_dt_day_of_week    0
#  is_weekend            0
#  amnt_log              0
#  doc_type              0
#  dtype: int64,
#  business_code         0
#  cust_payment_terms    0
#  mean_delay            0
#  due_dt_week           0
#  due_dt_mon            0
#  due_dt_day_of_week    0
#  is_weekend            0
#  amnt_log              0
#  doc_type              0
#  dtype: int64,
#  business_code         0
#  cust_payment_terms    0
#  mean_delay            0
#  due_dt_week           0
#  due_dt_mon            0
#  due_dt_day_of_week    0
#  is_weekend            0
#  amnt_log              0
#  doc_type              0
#  dtype: int64)

# %%
X_train.drop(["doc_type",'is_weekend'],axis=1,inplace=True)
X_val.drop(["doc_type",'is_weekend'],axis=1,inplace=True)
X_test1.drop(["doc_type",'is_weekend'],axis=1,inplace=True)

# %%
data_null.drop(["doc_type",'is_weekend'],axis=1,inplace=True)

# %% [markdown]
# #   *********** Testing and Predictions ***********

# %%
# Modeling & Accuracy Metrics
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# ### **1. Linear Regression**

# %%
# for X_val

clf = LinearRegression()
clf.fit(X_train, y_train)

# Predicting the Test Set Results
predicted = np.floor(clf.predict(X_val))

print(predicted)
# Out:
# [ 0.  0. -3. ... -2.  4.  1.]

# %%
y_val
# Out:
# 31998    1
# 31999    0
# 32000   -1
# 32001    1
# 32002    0
#         ..
# 35993   -4
# 35994    3
# 35995    0
# 35996    5
# 35997    0
# Name: delay, Length: 4000, dtype: int64

# %%
#Get mean squareed error(rms) for validation set
MSE_Score=mean_squared_error(y_val, predicted)
R2_Score=r2_score(y_val, predicted)
print(MSE_Score,R2_Score)
# Out:
# 42.52625 0.24779134111654577

# %%
#find rmse for validation set
rmse=np.sqrt(mean_squared_error(y_val,predicted))
rmse
# Out:
# 6.521215377519746

# %%
# for local test1 

clf = LinearRegression()
clf.fit(X_train, y_train)

# Predicting the Test Set Results
predicted1 = np.floor(clf.predict(X_test1))
import math
print(predicted1)
print('')
linear_accuracy = round(clf.score(X_train,y_train)*100,2)
print('accuracy : %.2f' % round(linear_accuracy,2),'%')
# Out:
# [-2.  1.  3. ...  1.  3. -3.]
#
# accuracy : 48.28 %

# %%
#Get mean squareed error(rms) for test set
MSE_Score=mean_squared_error(y_test1, predicted1)
R2_Score=r2_score(y_test1, predicted1)
print(MSE_Score)
print(R2_Score)
# Out:
# 68.50375
# 0.3985524067441859

# %%
#find root mean square error(rmse)
rmse=np.sqrt(mean_squared_error(y_test1,predicted1))
rmse
# Out:
# 8.276699221307972

# %% [markdown]
# ### **2. Gradient Boosting Regression**

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error


GBR_model = GradientBoostingRegressor(n_estimators=100, max_depth=4)
GBR_model.fit(X_train, y_train)
y_pred2 = GBR_model.predict(X_test1)
GBR_model_accuracy = round(GBR_model.score(X_train,y_train)*100,2)
print(round(GBR_model_accuracy,2),'%')
# Out:
# 61.52 %

# %%
mean_squared_error(y_test1,y_pred2)
# Out:
# 59.75497780075006

# %% [markdown]
# ### 3. Random Forest Regression

# %%
random_model = RandomForestRegressor(n_estimators=120)
random_model.fit(X_train, y_train)
y_pred3 = random_model.predict(X_test1)
random_model_accuracy = round(random_model.score(X_train,y_train)*100,2)
print(round(random_model_accuracy,2),'%')
# Out:
# 94.05 %

# %% [markdown]
# ##### Hyperparameter Tuning

# %%
random_model = RandomForestRegressor(n_estimators=1000, max_depth=150 , random_state=1)
random_model.fit(X_val, y_val)
y_pro = random_model.predict(X_test1)
random_model_accuracy = round(random_model.score(X_val,y_val)*100,2)
print(round(random_model_accuracy,2),'%')

# 94.16% was the highest i achieved but it kept changing so i applied random state on the next highest value.
# Out:
# 93.03 %

# %%
y_pred3
# Out:
# array([ 0.05      ,  0.43333333,  2.80833333, ...,  0.31666667,
#         1.        , -0.775     ])

# %%
MSE_Score1=mean_squared_error(y_test1,  y_pred3)
R2_Score1=r2_score(y_test1, y_pred3)
print(MSE_Score1)
print(R2_Score1)
# Out:
# 65.25300182040414
# 0.4270932482148886

# %%
random_model = RandomForestRegressor(n_estimators=120)
random_model.fit(X_train, y_train)
y_val_pred = random_model.predict(X_val)
random_model_accuracy = round(random_model.score(X_train,y_train)*100,2)
print(round(random_model_accuracy,2),'%')
# Out:
# 94.1 %

# %%
y_val_pred
# Out:
# array([ 0.26666667,  0.19166667, -3.59166667, ...,  0.675     ,
#         2.64166667,  6.375     ])

# %%
Y_valpred=y_val.copy()
Y_valpred=pd.DataFrame(Y_valpred)

# %%
Y_valpred['predicted']=np.floor(pd.Series(y_val_pred, Y_valpred.index))

# %%
Y_valpred
# Out:
#        delay  predicted
# 31998      1        0.0
# 31999      0        0.0
# 32000     -1       -4.0
# 32001      1        3.0
# 32002      0        1.0
# ...      ...        ...
# 35993     -4       -4.0
# 35994      3        1.0
# 35995      0        0.0
# 35996      5        2.0
# 35997      0        6.0
#
# [4000 rows x 2 columns]

# %%
def act_decile (x):
   
    if x <= 0: return "-15-0 days"
    elif x <= 15: return "0-15 days"
    elif x <= 30: return "15-30 days"
    elif x <= 45: return "30-45 days"
    elif x <= 60: return "45-60 days"
    else: return "60+ days"
    
Y_valpred['age_bin'] = Y_valpred['predicted'].apply(act_decile)

# %%
Y_valpred
# Out:
#        delay  predicted     age_bin
# 31998      1        0.0  -15-0 days
# 31999      0        0.0  -15-0 days
# 32000     -1       -4.0  -15-0 days
# 32001      1        3.0   0-15 days
# 32002      0        1.0   0-15 days
# ...      ...        ...         ...
# 35993     -4       -4.0  -15-0 days
# 35994      3        1.0   0-15 days
# 35995      0        0.0  -15-0 days
# 35996      5        2.0   0-15 days
# 35997      0        6.0   0-15 days
#
# [4000 rows x 3 columns]

# %%
Y_testpred=y_test1.copy()
Y_testpred=pd.DataFrame(Y_testpred)

# %%
Y_testpred['predicted']=np.floor(pd.Series(y_pred3, Y_testpred.index))

# %%
Y_testpred
# Out:
#        delay  predicted
# 35998      0        0.0
# 35999      0        0.0
# 36000     -4        2.0
# 36001      2        0.0
# 36002     -4       -4.0
# ...      ...        ...
# 39993     -8       -8.0
# 39994    -52      -48.0
# 39995      0        0.0
# 39996      3        1.0
# 39997     -1       -1.0
#
# [4000 rows x 2 columns]

# %%
Y_testpred['age_bin'] = Y_testpred['predicted'].apply(act_decile)

# %%
Y_testpred
# Out:
#        delay  predicted     age_bin
# 35998      0        0.0  -15-0 days
# 35999      0        0.0  -15-0 days
# 36000     -4        2.0   0-15 days
# 36001      2        0.0  -15-0 days
# 36002     -4       -4.0  -15-0 days
# ...      ...        ...         ...
# 39993     -8       -8.0  -15-0 days
# 39994    -52      -48.0  -15-0 days
# 39995      0        0.0  -15-0 days
# 39996      3        1.0   0-15 days
# 39997     -1       -1.0  -15-0 days
#
# [4000 rows x 3 columns]

# %%
# Plot histograph for prediction values of 
plt.hist(Y_testpred['predicted'],color='green')
plt.title("prediction density")
# Out:
# Text(0.5, 1.0, 'prediction density')

# %% [markdown]
# ### now lets predict the clear date of those null values

# %%
random_model = RandomForestRegressor(n_estimators=120)
random_model.fit(X_train, y_train)
y_null_pred = random_model.predict(data_null)
random_model_accuracy = round(random_model.score(X_train,y_train)*100,2)
print(round(random_model_accuracy,2),'%')
# Out:
# 94.02 %

# %%
y_null_pred
# Out:
# array([ 0.70833333, 17.08333333, -4.21666667, ..., -0.25833333,
#        -0.13333333,  0.45      ])

# %%
y_null_pred=np.round(pd.DataFrame(y_null_pred))

# %%
y_null_pred
# Out:
#          0
# 0      1.0
# 1     17.0
# 2     -4.0
# 3     -4.0
# 4     -0.0
# ...    ...
# 9995   5.0
# 9996  -4.0
# 9997  -0.0
# 9998  -0.0
# 9999   0.0
#
# [10000 rows x 1 columns]

# %%
y_null_pred=y_null_pred.rename(columns={0:'predicted'})
y_null_pred
# Out:
#       predicted
# 0           1.0
# 1          17.0
# 2          -4.0
# 3          -4.0
# 4          -0.0
# ...         ...
# 9995        5.0
# 9996       -4.0
# 9997       -0.0
# 9998       -0.0
# 9999        0.0
#
# [10000 rows x 1 columns]

# %%
y_null_pred['age_bin'] =y_null_pred['predicted'].apply(act_decile)

# %%
y_null_pred
# Out:
#       predicted     age_bin
# 0           1.0   0-15 days
# 1          17.0  15-30 days
# 2          -4.0  -15-0 days
# 3          -4.0  -15-0 days
# 4          -0.0  -15-0 days
# ...         ...         ...
# 9995        5.0   0-15 days
# 9996       -4.0  -15-0 days
# 9997       -0.0  -15-0 days
# 9998       -0.0  -15-0 days
# 9999        0.0  -15-0 days
#
# [10000 rows x 2 columns]

# %%
data_nat
#this is acopy of data_null(data with null clear dates) which i made above
# Out:
#       business_code cust_number       name_customer clear_date  buisness_year  \
# 2              U001  0200726979              BJ'S          NaN         2020.0
# 7              U001  0100031704    DELHAIZE systems        NaN         2020.0
# 8              U001  0200769623  WAL-MAR foundation        NaN         2020.0
# 13             U001  0200769623  WAL-MAR associates        NaN         2020.0
# 20             U001  0200723794             MID MO         NaN         2020.0
# ...             ...         ...                 ...        ...            ...
# 49983          CA02  0140105847        GORDON F llc        NaN         2020.0
# 49984          U001  0200769623  WAL-MAR associates        NaN         2020.0
# 49988          U001  0200729942             SA corp        NaN         2020.0
# 49996          U001  0200762301   C&S WH associates        NaN         2020.0
# 49997          U001  0200418007          AM systems        NaN         2020.0
#
#              doc_id posting_date  document_create_date  \
# 2      1.930750e+09   2020-04-08              20200406
# 7      1.930685e+09   2020-03-21              20200321
# 8      1.930607e+09   2020-03-05              20200305
# 13     1.930684e+09   2020-03-22              20200321
# 20     1.930747e+09   2020-04-05              20200404
# ...             ...          ...                   ...
# 49983  2.960627e+09   2020-04-07              20200407
# 49984  1.930611e+09   2020-03-06              20200306
# 49988  1.930844e+09   2020-04-30              20200430
# 49996  1.930637e+09   2020-03-11              20200310
# 49997  1.930675e+09   2020-03-24              20200320
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 2                    20200408   20200423.0              USD            RV
# 7                    20200321   20200405.0              USD            RV
# 8                    20200305   20200320.0              USD            RV
# 13                   20200322   20200406.0              USD            RV
# 20                   20200405   20200420.0              USD            RV
# ...                       ...          ...              ...           ...
# 49983                20200407   20200417.0              CAD            RV
# 49984                20200306   20200321.0              USD            RV
# 49988                20200430   20200515.0              USD            RV
# 49996                20200311   20200326.0              USD            RV
# 49997                20200324   20200408.0              USD            RV
#
#        posting_id  area_business  total_open_amount  baseline_create_date  \
# 2             1.0            NaN           17033.75            20200408.0
# 7             1.0            NaN          108430.66            20200321.0
# 8             1.0            NaN           38911.56            20200305.0
# 13            1.0            NaN           44224.52            20200322.0
# 20            1.0            NaN           48532.99            20200405.0
# ...           ...            ...                ...                   ...
# 49983         1.0            NaN           15587.00            20200407.0
# 49984         1.0            NaN           10447.18            20200306.0
# 49988         1.0            NaN           44233.65            20200430.0
# 49996         1.0            NaN           73655.45            20200311.0
# 49997         1.0            NaN             895.96            20200324.0
#
#       cust_payment_terms    invoice_id  isOpen
# 2                   NAA8  1.930750e+09       1
# 7                   NAA8  1.930685e+09       1
# 8                   NAH4  1.930607e+09       1
# 13                  NAH4  1.930684e+09       1
# 20                  NAA8  1.930747e+09       1
# ...                  ...           ...     ...
# 49983               CA10  2.960627e+09       1
# 49984               NAH4  1.930611e+09       1
# 49988               NAA8  1.930844e+09       1
# 49996               NAC6  1.930637e+09       1
# 49997               NAA8  1.930675e+09       1
#
# [10000 rows x 19 columns]

# %%
# i am making another copy so that if anything goes wrong with dataset then i wont have to rerun the whole code
dataset=data_nat.copy()
dataset
# Out:
#       business_code cust_number       name_customer clear_date  buisness_year  \
# 2              U001  0200726979              BJ'S          NaN         2020.0
# 7              U001  0100031704    DELHAIZE systems        NaN         2020.0
# 8              U001  0200769623  WAL-MAR foundation        NaN         2020.0
# 13             U001  0200769623  WAL-MAR associates        NaN         2020.0
# 20             U001  0200723794             MID MO         NaN         2020.0
# ...             ...         ...                 ...        ...            ...
# 49983          CA02  0140105847        GORDON F llc        NaN         2020.0
# 49984          U001  0200769623  WAL-MAR associates        NaN         2020.0
# 49988          U001  0200729942             SA corp        NaN         2020.0
# 49996          U001  0200762301   C&S WH associates        NaN         2020.0
# 49997          U001  0200418007          AM systems        NaN         2020.0
#
#              doc_id posting_date  document_create_date  \
# 2      1.930750e+09   2020-04-08              20200406
# 7      1.930685e+09   2020-03-21              20200321
# 8      1.930607e+09   2020-03-05              20200305
# 13     1.930684e+09   2020-03-22              20200321
# 20     1.930747e+09   2020-04-05              20200404
# ...             ...          ...                   ...
# 49983  2.960627e+09   2020-04-07              20200407
# 49984  1.930611e+09   2020-03-06              20200306
# 49988  1.930844e+09   2020-04-30              20200430
# 49996  1.930637e+09   2020-03-11              20200310
# 49997  1.930675e+09   2020-03-24              20200320
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 2                    20200408   20200423.0              USD            RV
# 7                    20200321   20200405.0              USD            RV
# 8                    20200305   20200320.0              USD            RV
# 13                   20200322   20200406.0              USD            RV
# 20                   20200405   20200420.0              USD            RV
# ...                       ...          ...              ...           ...
# 49983                20200407   20200417.0              CAD            RV
# 49984                20200306   20200321.0              USD            RV
# 49988                20200430   20200515.0              USD            RV
# 49996                20200311   20200326.0              USD            RV
# 49997                20200324   20200408.0              USD            RV
#
#        posting_id  area_business  total_open_amount  baseline_create_date  \
# 2             1.0            NaN           17033.75            20200408.0
# 7             1.0            NaN          108430.66            20200321.0
# 8             1.0            NaN           38911.56            20200305.0
# 13            1.0            NaN           44224.52            20200322.0
# 20            1.0            NaN           48532.99            20200405.0
# ...           ...            ...                ...                   ...
# 49983         1.0            NaN           15587.00            20200407.0
# 49984         1.0            NaN           10447.18            20200306.0
# 49988         1.0            NaN           44233.65            20200430.0
# 49996         1.0            NaN           73655.45            20200311.0
# 49997         1.0            NaN             895.96            20200324.0
#
#       cust_payment_terms    invoice_id  isOpen
# 2                   NAA8  1.930750e+09       1
# 7                   NAA8  1.930685e+09       1
# 8                   NAH4  1.930607e+09       1
# 13                  NAH4  1.930684e+09       1
# 20                  NAA8  1.930747e+09       1
# ...                  ...           ...     ...
# 49983               CA10  2.960627e+09       1
# 49984               NAH4  1.930611e+09       1
# 49988               NAA8  1.930844e+09       1
# 49996               NAC6  1.930637e+09       1
# 49997               NAA8  1.930675e+09       1
#
# [10000 rows x 19 columns]

# %%
new=y_null_pred['predicted']
new
# Out:
# 0        1.0
# 1       17.0
# 2       -4.0
# 3       -4.0
# 4       -0.0
#         ...
# 9995     5.0
# 9996    -4.0
# 9997    -0.0
# 9998    -0.0
# 9999     0.0
# Name: predicted, Length: 10000, dtype: float64

# %%
dataset['due_in_date']=dataset['due_in_date'].astype('int')

# %%
dataset['due_in_date']=dataset['due_in_date'].astype('str')

# %%
dataset['due_in_date']=pd.to_datetime(dataset['due_in_date'],format='%Y-%m-%d').dt.date

# %%
dataset.reset_index(drop=True,inplace=True)
#resetting the index before appending new data

# %%
dataset['y_pred_days']=new
dataset
# Out:
#      business_code cust_number       name_customer clear_date  buisness_year  \
# 0             U001  0200726979              BJ'S          NaN         2020.0
# 1             U001  0100031704    DELHAIZE systems        NaN         2020.0
# 2             U001  0200769623  WAL-MAR foundation        NaN         2020.0
# 3             U001  0200769623  WAL-MAR associates        NaN         2020.0
# 4             U001  0200723794             MID MO         NaN         2020.0
# ...            ...         ...                 ...        ...            ...
# 9995          CA02  0140105847        GORDON F llc        NaN         2020.0
# 9996          U001  0200769623  WAL-MAR associates        NaN         2020.0
# 9997          U001  0200729942             SA corp        NaN         2020.0
# 9998          U001  0200762301   C&S WH associates        NaN         2020.0
# 9999          U001  0200418007          AM systems        NaN         2020.0
#
#             doc_id posting_date  document_create_date  document_create_date.1  \
# 0     1.930750e+09   2020-04-08              20200406                20200408
# 1     1.930685e+09   2020-03-21              20200321                20200321
# 2     1.930607e+09   2020-03-05              20200305                20200305
# 3     1.930684e+09   2020-03-22              20200321                20200322
# 4     1.930747e+09   2020-04-05              20200404                20200405
# ...            ...          ...                   ...                     ...
# 9995  2.960627e+09   2020-04-07              20200407                20200407
# 9996  1.930611e+09   2020-03-06              20200306                20200306
# 9997  1.930844e+09   2020-04-30              20200430                20200430
# 9998  1.930637e+09   2020-03-11              20200310                20200311
# 9999  1.930675e+09   2020-03-24              20200320                20200324
#
#      due_in_date invoice_currency document type  posting_id  area_business  \
# 0     2020-04-23              USD            RV         1.0            NaN
# 1     2020-04-05              USD            RV         1.0            NaN
# 2     2020-03-20              USD            RV         1.0            NaN
# 3     2020-04-06              USD            RV         1.0            NaN
# 4     2020-04-20              USD            RV         1.0            NaN
# ...          ...              ...           ...         ...            ...
# 9995  2020-04-17              CAD            RV         1.0            NaN
# 9996  2020-03-21              USD            RV         1.0            NaN
# 9997  2020-05-15              USD            RV         1.0            NaN
# 9998  2020-03-26              USD            RV         1.0            NaN
# 9999  2020-04-08              USD            RV         1.0            NaN
#
#       total_open_amount  baseline_create_date cust_payment_terms  \
# 0              17033.75            20200408.0               NAA8
# 1             108430.66            20200321.0               NAA8
# 2              38911.56            20200305.0               NAH4
# 3              44224.52            20200322.0               NAH4
# 4              48532.99            20200405.0               NAA8
# ...                 ...                   ...                ...
# 9995           15587.00            20200407.0               CA10
# 9996           10447.18            20200306.0               NAH4
# 9997           44233.65            20200430.0               NAA8
# 9998           73655.45            20200311.0               NAC6
# 9999             895.96            20200324.0               NAA8
#
#         invoice_id  isOpen  y_pred_days
# 0     1.930750e+09       1          1.0
# 1     1.930685e+09       1         17.0
# 2     1.930607e+09       1         -4.0
# 3     1.930684e+09       1         -4.0
# 4     1.930747e+09       1         -0.0
# ...            ...     ...          ...
# 9995  2.960627e+09       1          5.0
# 9996  1.930611e+09       1         -4.0
# 9997  1.930844e+09       1         -0.0
# 9998  1.930637e+09       1         -0.0
# 9999  1.930675e+09       1          0.0
#
# [10000 rows x 20 columns]

# %%
#here i am converting the predicted days to a datetime datatype so that it can be added to another datetime datatype

dataset['y_pred_days']=pd.to_timedelta(dataset['y_pred_days'], unit='D')
dataset.drop('clear_date',axis=1,inplace=True)

# %%
#get predicted clear date bt adding due date and pred days and converting predicted clear date into datetime type 
dataset['predicted_clear_date']=dataset['due_in_date']+ dataset['y_pred_days']
dataset['predicted_clear_date']=pd.to_datetime(dataset['predicted_clear_date']).dt.date

# %%
binn=y_null_pred['age_bin']
binn
# Out:
# 0        0-15 days
# 1       15-30 days
# 2       -15-0 days
# 3       -15-0 days
# 4       -15-0 days
#            ...
# 9995     0-15 days
# 9996    -15-0 days
# 9997    -15-0 days
# 9998    -15-0 days
# 9999    -15-0 days
# Name: age_bin, Length: 10000, dtype: object

# %%
#also appending age bin the out final result

dataset['age_bin']=binn

# %% [markdown]
# #  **Final Dataset**

# %%
dataset
# Out:
#      business_code cust_number       name_customer  buisness_year  \
# 0             U001  0200726979              BJ'S           2020.0
# 1             U001  0100031704    DELHAIZE systems         2020.0
# 2             U001  0200769623  WAL-MAR foundation         2020.0
# 3             U001  0200769623  WAL-MAR associates         2020.0
# 4             U001  0200723794             MID MO          2020.0
# ...            ...         ...                 ...            ...
# 9995          CA02  0140105847        GORDON F llc         2020.0
# 9996          U001  0200769623  WAL-MAR associates         2020.0
# 9997          U001  0200729942             SA corp         2020.0
# 9998          U001  0200762301   C&S WH associates         2020.0
# 9999          U001  0200418007          AM systems         2020.0
#
#             doc_id posting_date  document_create_date  document_create_date.1  \
# 0     1.930750e+09   2020-04-08              20200406                20200408
# 1     1.930685e+09   2020-03-21              20200321                20200321
# 2     1.930607e+09   2020-03-05              20200305                20200305
# 3     1.930684e+09   2020-03-22              20200321                20200322
# 4     1.930747e+09   2020-04-05              20200404                20200405
# ...            ...          ...                   ...                     ...
# 9995  2.960627e+09   2020-04-07              20200407                20200407
# 9996  1.930611e+09   2020-03-06              20200306                20200306
# 9997  1.930844e+09   2020-04-30              20200430                20200430
# 9998  1.930637e+09   2020-03-11              20200310                20200311
# 9999  1.930675e+09   2020-03-24              20200320                20200324
#
#      due_in_date invoice_currency  ... posting_id  area_business  \
# 0     2020-04-23              USD  ...        1.0            NaN
# 1     2020-04-05              USD  ...        1.0            NaN
# 2     2020-03-20              USD  ...        1.0            NaN
# 3     2020-04-06              USD  ...        1.0            NaN
# 4     2020-04-20              USD  ...        1.0            NaN
# ...          ...              ...  ...        ...            ...
# 9995  2020-04-17              CAD  ...        1.0            NaN
# 9996  2020-03-21              USD  ...        1.0            NaN
# 9997  2020-05-15              USD  ...        1.0            NaN
# 9998  2020-03-26              USD  ...        1.0            NaN
# 9999  2020-04-08              USD  ...        1.0            NaN
#
#       total_open_amount  baseline_create_date  cust_payment_terms  \
# 0              17033.75            20200408.0                NAA8
# 1             108430.66            20200321.0                NAA8
# 2              38911.56            20200305.0                NAH4
# 3              44224.52            20200322.0                NAH4
# 4              48532.99            20200405.0                NAA8
# ...                 ...                   ...                 ...
# 9995           15587.00            20200407.0                CA10
# 9996           10447.18            20200306.0                NAH4
# 9997           44233.65            20200430.0                NAA8
# 9998           73655.45            20200311.0                NAC6
# 9999             895.96            20200324.0                NAA8
#
#         invoice_id  isOpen  y_pred_days predicted_clear_date     age_bin
# 0     1.930750e+09       1       1 days           2020-04-24   0-15 days
# 1     1.930685e+09       1      17 days           2020-04-22  15-30 days
# 2     1.930607e+09       1      -4 days           2020-03-16  -15-0 days
# 3     1.930684e+09       1      -4 days           2020-04-02  -15-0 days
# 4     1.930747e+09       1       0 days           2020-04-20  -15-0 days
# ...            ...     ...          ...                  ...         ...
# 9995  2.960627e+09       1       5 days           2020-04-22   0-15 days
# 9996  1.930611e+09       1      -4 days           2020-03-17  -15-0 days
# 9997  1.930844e+09       1       0 days           2020-05-15  -15-0 days
# 9998  1.930637e+09       1       0 days           2020-03-26  -15-0 days
# 9999  1.930675e+09       1       0 days           2020-04-08  -15-0 days
#
# [10000 rows x 21 columns]

# %%
from IPython.display import FileLink, FileLinks

dataset.to_csv(r"C:\Users\teja\Downloads\dataset.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-204-8aa524d45547> in <module>
#       2
#       3 dataset.to_csv(r"C:\Users\teja\Downloads\dataset.csv", index=False)
# ----> 4 df.to_excel('/path/to/data.xlsx', index=False)
#       5
#
# NameError: name 'df' is not defined
